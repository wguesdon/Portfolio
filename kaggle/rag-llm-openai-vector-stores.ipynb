# %%
# !pip install --upgrade openai  > /dev/null 2>&1
# !pip install faiss-cpu==1.7.4  > /dev/null 2>&1
# !pip install tiktoken==0.5.2  > /dev/null 2>&1
# !pip install numpy==1.24.3 > /dev/null 2>&1

# %%
# !cp /kaggle/input/creating-a-knowledge-base-paid-models/*.md /kaggle/working/
# !cp /kaggle/input/openai-to-z-challenge-deep-research-reports/*.md /kaggle/working/

# %%
# !rm __notebook__.ipynb
# !rm __output__.json
# !rm __results__.html
# !rm custom.css
# Out:
# rm: cannot remove '__output__.json': No such file or directory
# rm: cannot remove '__results__.html': No such file or directory
# rm: cannot remove 'custom.css': No such file or directory

# %%
# !ls /kaggle/working/
# Out:
# deep_research_Amazonian_Dark_Earths.md
# deep_research_competition_strategies_ideas.md
# deep_research_Detecting_Archaeological_Sites_SOTA.md
# deep_research_Effectiveness_of_LIDAR.md
# deep_research_Known_Archaeological_Sites_2.md
# deep_research_Known_Archaeological_Sites_3.md
# deep_research_Known_Archaeological_Sites.md
# deep_research_Kuhikugu_Archaeological.md
# deep_research_Likely_Locations_of_Archaeological.md
# deep_research_Machine_Learning_Models_2.md
# deep_research_Machine_Learning_Models.md
# deep_research_Open_Access_LiDAR_Datasets.md
# deep_research_Suspected_Unconfirmed_Sites.md
# __notebook__.ipynb
# question_10_anthropic_claude-3-haiku_online_20250522190620.md
# question_10_meta-llama_llama-4-scout_online_20250522190644.md
# question_10_openai_gpt-4.1-mini_online_20250522190606.md
# question_11_anthropic_claude-3-haiku_online_20250522190717.md
# question_11_meta-llama_llama-4-scout_online_20250522190732.md
# question_11_openai_gpt-4.1-mini_online_20250522190706.md
# question_12_anthropic_claude-3-haiku_online_20250522190814.md
# question_12_meta-llama_llama-4-scout_online_20250522190829.md
# question_12_openai_gpt-4.1-mini_online_20250522190759.md
# question_13_anthropic_claude-3-haiku_online_20250522190907.md
# question_13_meta-llama_llama-4-scout_online_20250522190921.md
# question_13_openai_gpt-4.1-mini_online_20250522190856.md
# question_14_anthropic_claude-3-haiku_online_20250522190953.md
# question_14_meta-llama_llama-4-scout_online_20250522191007.md
# question_14_openai_gpt-4.1-mini_online_20250522190943.md
# question_15_anthropic_claude-3-haiku_online_20250522191050.md
# question_15_meta-llama_llama-4-scout_online_20250522191059.md
# question_15_openai_gpt-4.1-mini_online_20250522191038.md
# question_16_anthropic_claude-3-haiku_online_20250522191155.md
# question_16_meta-llama_llama-4-scout_online_20250522191209.md
# question_16_openai_gpt-4.1-mini_online_20250522191145.md
# question_17_anthropic_claude-3-haiku_online_20250522191243.md
# question_17_meta-llama_llama-4-scout_online_20250522191312.md
# question_17_openai_gpt-4.1-mini_online_20250522191230.md
# question_18_anthropic_claude-3-haiku_online_20250522191347.md
# question_18_meta-llama_llama-4-scout_online_20250522191402.md
# question_18_openai_gpt-4.1-mini_online_20250522191335.md
# question_19_anthropic_claude-3-haiku_online_20250522191447.md
# question_19_meta-llama_llama-4-scout_online_20250522191518.md
# question_19_openai_gpt-4.1-mini_online_20250522191434.md
# question_1_anthropic_claude-3-haiku_online_20250522185546.md
# question_1_meta-llama_llama-4-scout_online_20250522185601.md
# question_1_openai_gpt-4.1-mini_online_20250522185533.md
# question_20_anthropic_claude-3-haiku_online_20250522191547.md
# question_20_meta-llama_llama-4-scout_online_20250522191603.md
# question_20_openai_gpt-4.1-mini_online_20250522191537.md
# question_21_anthropic_claude-3-haiku_online_20250522191653.md
# question_21_meta-llama_llama-4-scout_online_20250522191708.md
# question_21_openai_gpt-4.1-mini_online_20250522191638.md
# question_22_anthropic_claude-3-haiku_online_20250522191753.md
# question_22_meta-llama_llama-4-scout_online_20250522191809.md
# question_22_openai_gpt-4.1-mini_online_20250522191742.md
# question_23_anthropic_claude-3-haiku_online_20250522191849.md
# question_23_meta-llama_llama-4-scout_online_20250522191901.md
# question_23_openai_gpt-4.1-mini_online_20250522191835.md
# question_24_anthropic_claude-3-haiku_online_20250522191941.md
# question_24_meta-llama_llama-4-scout_online_20250522191955.md
# question_24_openai_gpt-4.1-mini_online_20250522191929.md
# question_25_anthropic_claude-3-haiku_online_20250522192045.md
# question_25_meta-llama_llama-4-scout_online_20250522192120.md
# question_25_openai_gpt-4.1-mini_online_20250522192024.md
# question_26_anthropic_claude-3-haiku_online_20250522192156.md
# question_26_meta-llama_llama-4-scout_online_20250522192213.md
# question_26_openai_gpt-4.1-mini_online_20250522192145.md
# question_27_anthropic_claude-3-haiku_online_20250522192247.md
# question_27_meta-llama_llama-4-scout_online_20250522192301.md
# question_27_openai_gpt-4.1-mini_online_20250522192234.md
# question_28_anthropic_claude-3-haiku_online_20250522192340.md
# question_28_meta-llama_llama-4-scout_online_20250522192356.md
# question_28_openai_gpt-4.1-mini_online_20250522192331.md
# question_29_anthropic_claude-3-haiku_online_20250522192430.md
# question_29_meta-llama_llama-4-scout_online_20250522192445.md
# question_29_openai_gpt-4.1-mini_online_20250522192419.md
# question_2_anthropic_claude-3-haiku_online_20250522185649.md
# question_2_meta-llama_llama-4-scout_online_20250522185705.md
# question_2_openai_gpt-4.1-mini_online_20250522185633.md
# question_30_anthropic_claude-3-haiku_online_20250522192528.md
# question_30_meta-llama_llama-4-scout_online_20250522192534.md
# question_30_openai_gpt-4.1-mini_online_20250522192511.md
# question_31_anthropic_claude-3-haiku_online_20250522192611.md
# question_31_meta-llama_llama-4-scout_online_20250522192622.md
# question_31_openai_gpt-4.1-mini_online_20250522192558.md
# question_32_anthropic_claude-3-haiku_online_20250522192708.md
# question_32_meta-llama_llama-4-scout_online_20250522192721.md
# question_32_openai_gpt-4.1-mini_online_20250522192653.md
# question_33_anthropic_claude-3-haiku_online_20250522192802.md
# question_33_meta-llama_llama-4-scout_online_20250522192837.md
# question_33_openai_gpt-4.1-mini_online_20250522192747.md
# question_34_anthropic_claude-3-haiku_online_20250522192917.md
# question_34_meta-llama_llama-4-scout_online_20250522192936.md
# question_34_openai_gpt-4.1-mini_online_20250522192907.md
# question_35_anthropic_claude-3-haiku_online_20250522193015.md
# question_35_meta-llama_llama-4-scout_online_20250522193036.md
# question_35_openai_gpt-4.1-mini_online_20250522193003.md
# question_36_anthropic_claude-3-haiku_online_20250522193132.md
# question_36_meta-llama_llama-4-scout_online_20250522193143.md
# question_36_openai_gpt-4.1-mini_online_20250522193117.md
# question_37_anthropic_claude-3-haiku_online_20250522193227.md
# question_37_meta-llama_llama-4-scout_online_20250522193306.md
# question_37_openai_gpt-4.1-mini_online_20250522193216.md
# question_38_anthropic_claude-3-haiku_online_20250522193348.md
# question_38_meta-llama_llama-4-scout_online_20250522193414.md
# question_38_openai_gpt-4.1-mini_online_20250522193332.md
# question_39_anthropic_claude-3-haiku_online_20250522193456.md
# question_39_meta-llama_llama-4-scout_online_20250522193510.md
# question_39_openai_gpt-4.1-mini_online_20250522193441.md
# question_3_anthropic_claude-3-haiku_online_20250522185757.md
# question_3_meta-llama_llama-4-scout_online_20250522185813.md
# question_3_openai_gpt-4.1-mini_online_20250522185742.md
# question_40_anthropic_claude-3-haiku_online_20250522193549.md
# question_40_meta-llama_llama-4-scout_online_20250522193605.md
# question_40_openai_gpt-4.1-mini_online_20250522193538.md
# question_41_anthropic_claude-3-haiku_online_20250522193647.md
# question_41_meta-llama_llama-4-scout_online_20250522193701.md
# question_41_openai_gpt-4.1-mini_online_20250522193632.md
# question_42_anthropic_claude-3-haiku_online_20250522193744.md
# question_42_meta-llama_llama-4-scout_online_20250522193757.md
# question_42_openai_gpt-4.1-mini_online_20250522193728.md
# question_43_anthropic_claude-3-haiku_online_20250522193852.md
# question_43_meta-llama_llama-4-scout_online_20250522193907.md
# question_43_openai_gpt-4.1-mini_online_20250522193837.md
# question_44_anthropic_claude-3-haiku_online_20250522193954.md
# question_44_meta-llama_llama-4-scout_online_20250522194011.md
# question_44_openai_gpt-4.1-mini_online_20250522193937.md
# question_45_anthropic_claude-3-haiku_online_20250522194058.md
# question_45_meta-llama_llama-4-scout_online_20250522194133.md
# question_45_openai_gpt-4.1-mini_online_20250522194046.md
# question_46_anthropic_claude-3-haiku_online_20250522194215.md
# question_46_meta-llama_llama-4-scout_online_20250522194230.md
# question_46_openai_gpt-4.1-mini_online_20250522194202.md
# question_47_anthropic_claude-3-haiku_online_20250522194321.md
# question_47_meta-llama_llama-4-scout_online_20250522194342.md
# question_47_openai_gpt-4.1-mini_online_20250522194259.md
# question_48_anthropic_claude-3-haiku_online_20250522194423.md
# question_48_meta-llama_llama-4-scout_online_20250522194456.md
# question_48_openai_gpt-4.1-mini_online_20250522194410.md
# question_49_anthropic_claude-3-haiku_online_20250522194537.md
# question_49_meta-llama_llama-4-scout_online_20250522194600.md
# question_49_openai_gpt-4.1-mini_online_20250522194524.md
# question_4_anthropic_claude-3-haiku_online_20250522185908.md
# question_4_meta-llama_llama-4-scout_online_20250522185926.md
# question_4_openai_gpt-4.1-mini_online_20250522185853.md
# question_50_anthropic_claude-3-haiku_online_20250522194637.md
# question_50_meta-llama_llama-4-scout_online_20250522194651.md
# question_50_openai_gpt-4.1-mini_online_20250522194621.md
# question_51_anthropic_claude-3-haiku_online_20250522194723.md
# question_51_meta-llama_llama-4-scout_online_20250522194735.md
# question_51_openai_gpt-4.1-mini_online_20250522194712.md
# question_52_anthropic_claude-3-haiku_online_20250522194820.md
# question_52_meta-llama_llama-4-scout_online_20250522194833.md
# question_52_openai_gpt-4.1-mini_online_20250522194806.md
# question_53_anthropic_claude-3-haiku_online_20250522194916.md
# question_53_meta-llama_llama-4-scout_online_20250522194924.md
# question_53_openai_gpt-4.1-mini_online_20250522194903.md
# question_54_anthropic_claude-3-haiku_online_20250522195010.md
# question_54_meta-llama_llama-4-scout_online_20250522195037.md
# question_54_openai_gpt-4.1-mini_online_20250522194956.md
# question_55_anthropic_claude-3-haiku_online_20250522195112.md
# question_55_meta-llama_llama-4-scout_online_20250522195137.md
# question_55_openai_gpt-4.1-mini_online_20250522195059.md
# question_56_anthropic_claude-3-haiku_online_20250522195214.md
# question_56_meta-llama_llama-4-scout_online_20250522195241.md
# question_56_openai_gpt-4.1-mini_online_20250522195202.md
# question_57_anthropic_claude-3-haiku_online_20250522195333.md
# question_57_meta-llama_llama-4-scout_online_20250522195401.md
# question_57_openai_gpt-4.1-mini_online_20250522195315.md
# question_58_anthropic_claude-3-haiku_online_20250522195436.md
# question_58_meta-llama_llama-4-scout_online_20250522195502.md
# question_58_openai_gpt-4.1-mini_online_20250522195423.md
# question_59_anthropic_claude-3-haiku_online_20250522195542.md
# question_59_meta-llama_llama-4-scout_online_20250522195604.md
# question_59_openai_gpt-4.1-mini_online_20250522195529.md
# question_5_anthropic_claude-3-haiku_online_20250522190025.md
# question_5_meta-llama_llama-4-scout_online_20250522190051.md
# question_5_openai_gpt-4.1-mini_online_20250522190010.md
# question_60_anthropic_claude-3-haiku_online_20250522195638.md
# question_60_meta-llama_llama-4-scout_online_20250522195653.md
# question_60_openai_gpt-4.1-mini_online_20250522195625.md
# question_61_anthropic_claude-3-haiku_online_20250522195736.md
# question_61_meta-llama_llama-4-scout_online_20250522195749.md
# question_61_openai_gpt-4.1-mini_online_20250522195723.md
# question_62_anthropic_claude-3-haiku_online_20250522195843.md
# question_62_meta-llama_llama-4-scout_online_20250522195914.md
# question_62_openai_gpt-4.1-mini_online_20250522195830.md
# question_63_anthropic_claude-3-haiku_online_20250522200000.md
# question_63_meta-llama_llama-4-scout_online_20250522200016.md
# question_63_openai_gpt-4.1-mini_online_20250522195944.md
# question_64_anthropic_claude-3-haiku_online_20250522200111.md
# question_64_meta-llama_llama-4-scout_online_20250522200130.md
# question_64_openai_gpt-4.1-mini_online_20250522200056.md
# question_65_anthropic_claude-3-haiku_online_20250522200217.md
# question_65_meta-llama_llama-4-scout_online_20250522200243.md
# question_65_openai_gpt-4.1-mini_online_20250522200200.md
# question_66_anthropic_claude-3-haiku_online_20250522200319.md
# question_66_meta-llama_llama-4-scout_online_20250522200331.md
# question_66_openai_gpt-4.1-mini_online_20250522200306.md
# question_67_anthropic_claude-3-haiku_online_20250522200414.md
# question_67_meta-llama_llama-4-scout_online_20250522200429.md
# question_67_openai_gpt-4.1-mini_online_20250522200401.md
# question_68_anthropic_claude-3-haiku_online_20250522200513.md
# question_68_meta-llama_llama-4-scout_online_20250522200600.md
# question_68_openai_gpt-4.1-mini_online_20250522200458.md
# question_69_anthropic_claude-3-haiku_online_20250522200642.md
# question_69_meta-llama_llama-4-scout_online_20250522200658.md
# question_69_openai_gpt-4.1-mini_online_20250522200628.md
# question_6_anthropic_claude-3-haiku_online_20250522190141.md
# question_6_meta-llama_llama-4-scout_online_20250522190157.md
# question_6_openai_gpt-4.1-mini_online_20250522190126.md
# question_70_anthropic_claude-3-haiku_online_20250522200739.md
# question_70_meta-llama_llama-4-scout_online_20250522200809.md
# question_70_openai_gpt-4.1-mini_online_20250522200727.md
# question_71_anthropic_claude-3-haiku_online_20250522200901.md
# question_71_meta-llama_llama-4-scout_online_20250522200931.md
# question_71_openai_gpt-4.1-mini_online_20250522200848.md
# question_72_anthropic_claude-3-haiku_online_20250522201015.md
# question_72_meta-llama_llama-4-scout_online_20250522201039.md
# question_72_openai_gpt-4.1-mini_online_20250522201000.md
# question_73_anthropic_claude-3-haiku_online_20250522201129.md
# question_73_meta-llama_llama-4-scout_online_20250522201158.md
# question_73_openai_gpt-4.1-mini_online_20250522201116.md
# question_74_anthropic_claude-3-haiku_online_20250522201242.md
# question_74_meta-llama_llama-4-scout_online_20250522201303.md
# question_74_openai_gpt-4.1-mini_online_20250522201227.md
# question_75_anthropic_claude-3-haiku_online_20250522201344.md
# question_75_meta-llama_llama-4-scout_online_20250522201359.md
# question_75_openai_gpt-4.1-mini_online_20250522201330.md
# question_76_anthropic_claude-3-haiku_online_20250522201445.md
# question_76_meta-llama_llama-4-scout_online_20250522201519.md
# question_76_openai_gpt-4.1-mini_online_20250522201429.md
# question_7_anthropic_claude-3-haiku_online_20250522190233.md
# question_7_meta-llama_llama-4-scout_online_20250522190258.md
# question_7_openai_gpt-4.1-mini_online_20250522190220.md
# question_8_anthropic_claude-3-haiku_online_20250522190359.md
# question_8_meta-llama_llama-4-scout_online_20250522190438.md
# question_8_openai_gpt-4.1-mini_online_20250522190346.md
# question_9_anthropic_claude-3-haiku_online_20250522190516.md
# question_9_meta-llama_llama-4-scout_online_20250522190530.md
# question_9_openai_gpt-4.1-mini_online_20250522190505.md

# %% [markdown]
# # RAG-LLM Using OpenAI Vector Store
# I tried the LangChain approach, but I encountered dependency issues.

# %%
import os
import glob
import itertools
import time
import httpx
from openai import OpenAI, BadRequestError
from datetime import datetime
from IPython.display import display, Markdown
from typing import Optional, List

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
os.environ["OPENAI_API_KEY"] = user_secrets.get_secret("openai_key")

# %%
# Configuration
DIR = "/kaggle/working/"
timestamp = datetime.now().strftime("%Y%m%d-%H%M%S")
VECTOR_STORE_NAME = f"OpenAI_challenge_{timestamp}"
print(VECTOR_STORE_NAME)
SEARCH_K = 5
CHAT_MODEL = "gpt-4.1" #gpt-4o o3-mini
TEMPERATURE = 0.2
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# Initialize OpenAI client
client = OpenAI()

def get_or_create_vector_store(name: str) -> str:
    """
    Retrieves an existing vector store by name or creates a new one.
    Returns the vector_store_id.
    """
    stores = client.vector_stores.list()
    for store in stores.data:
        if store.name == name:
            print(f"Found existing vector store '{name}' (id={store.id})")
            return store.id
    vs = client.vector_stores.create(name=name)
    print(f"Created new vector store '{name}' (id={vs.id})")
    return vs.id

def upload_to_vector_store(
    dir: str,
    vector_store_id: str,
    extensions: tuple[str, ...] = ("pdf", "md", "markdown", "txt"),
    min_bytes: int = 1,  # skip files smaller than this
):
    """
    Upload every file in *dir* whose extension appears in *extensions* to OpenAI
    and index it into the given vector store, skipping empty files.

    Parameters
    ----------
    dir : str
        Folder to scan.
    vector_store_id : str
        ID of the target vector store.
    extensions : tuple[str, ...], optional
        Allowed file extensions (case-insensitive, *without* the leading dot).
    min_bytes : int, optional
        Minimum file size to upload; defaults to 1 byte (skip blank files).
    """
    exts = [ext.lower().lstrip(".") for ext in extensions]
    patterns = (os.path.join(dir, f"*.{ext}") for ext in exts)
    file_paths = list(
        itertools.chain.from_iterable(glob.glob(p, recursive=False) for p in patterns)
    )

    if not file_paths:
        print(f"No files with extensions {exts} found in {dir}")
        return

    for path in file_paths:
        filename = os.path.basename(path)

        # ── Skip zero-byte (or very small) files ──────────────────────────────
        size = os.path.getsize(path)
        if size < min_bytes:
            print(f"⚠️  Skipping {filename} (size {size} bytes)")
            continue

        print(f"Uploading {filename} ({size} bytes)…")
        try:
            with open(path, "rb") as fp:
                file_resp = client.files.create(file=fp, purpose="assistants")

            client.vector_stores.files.create(
                vector_store_id=vector_store_id,
                file_id=file_resp.id,
            )
            print(f"Indexed {filename} (file_id={file_resp.id})")
            time.sleep(0.2)  # gentle rate limit

        except BadRequestError as e:
            # Catch other per-file errors so the loop keeps going
            print(f"❌  OpenAI rejected {filename}: {e}")

def search_vector_store(vector_store_id: str, query: str) -> list:
    """
    Queries the OpenAI Vector Store via HTTP and returns up to SEARCH_K items.
    """
    if not OPENAI_API_KEY:
        raise ValueError("OPENAI_API_KEY environment variable not set")
    url = f"https://api.openai.com/v1/vector_stores/{vector_store_id}/search"
    headers = {
        "Authorization": f"Bearer {OPENAI_API_KEY}",
        "Content-Type": "application/json",
        "OpenAI-Beta": "assistants=v2"
    }
    payload = {"query": query}
    resp = httpx.post(url, headers=headers, json=payload)
    resp.raise_for_status()
    data = resp.json().get("data", [])
    # limit to top SEARCH_K
    return data[:SEARCH_K]


def answer_question(vector_store_id: str, question: str) -> str:
    """
    Retrieves relevant passages and asks the chat model to synthesize an answer.
    """
    # 1. Retrieve top passages
    items = search_vector_store(vector_store_id, question)
    # 2. Build context string
    context_parts = []
    for item in items:
        filename = item.get("filename", "unknown")
        for passage in item.get("content", []):
            context_parts.append(f"Source: {filename}\n{passage.get('text', '')}")
    context = "\n---\n".join(context_parts)

    # 3. Create chat messages
    system_msg = {
        "role": "system",
        "content": (
            "You are an expert in Maya archaeology and remote sensing. "
            "Use the provided context to answer precisely, citing sources when relevant."
        )
    }
    user_msg = {
        "role": "user",
        "content": (
            f"Context passages:\n{context}\n\n"
            f"Answer the following question: {question}"
        )
    }

    # 4. Call chat completion
    response = client.chat.completions.create(
        model=CHAT_MODEL,
        messages=[system_msg, user_msg],
        temperature=TEMPERATURE,
        max_tokens=800
    )

    return response.choices[0].message.content

def delete_vector_store_files(vector_store_id: str) -> int:
    """
    Delete all files associated with a vector store.
    
    Parameters
    ----------
    vector_store_id : str
        ID of the vector store whose files should be deleted.
    
    Returns
    -------
    int
        Number of files deleted.
    """
    deleted_count = 0
    
    try:
        # List all files in the vector store
        files = client.vector_stores.files.list(vector_store_id=vector_store_id)
        
        for file in files.data:
            try:
                # First, remove the file from the vector store
                client.vector_stores.files.delete(
                    vector_store_id=vector_store_id,
                    file_id=file.id
                )
                
                # Then delete the actual file
                client.files.delete(file.id)
                print(f"✓ Deleted file {file.id}")
                deleted_count += 1
                time.sleep(0.1)  # Rate limiting
                
            except Exception as e:
                print(f"❌ Error deleting file {file.id}: {e}")
                
    except Exception as e:
        print(f"❌ Error listing files for vector store {vector_store_id}: {e}")
    
    return deleted_count

def delete_vector_store(vector_store_id: str) -> bool:
    """
    Delete a vector store.
    
    Parameters
    ----------
    vector_store_id : str
        ID of the vector store to delete.
    
    Returns
    -------
    bool
        True if successfully deleted, False otherwise.
    """
    try:
        client.vector_stores.delete(vector_store_id)
        print(f"✓ Deleted vector store {vector_store_id}")
        return True
    except Exception as e:
        print(f"❌ Error deleting vector store {vector_store_id}: {e}")
        return False

def cleanup_vector_store(vector_store_id: str) -> None:
    """
    Complete cleanup: delete all files and the vector store.
    
    Parameters
    ----------
    vector_store_id : str
        ID of the vector store to completely remove.
    """
    print(f"\n🧹 Starting cleanup for vector store {vector_store_id}")
    
    # Step 1: Delete all files
    print("\n📄 Deleting files...")
    files_deleted = delete_vector_store_files(vector_store_id)
    print(f"Deleted {files_deleted} files")
    
    # Step 2: Delete the vector store
    print("\n🗑️  Deleting vector store...")
    if delete_vector_store(vector_store_id):
        print("\n✅ Cleanup complete!")
    else:
        print("\n⚠️  Cleanup completed with errors")

def cleanup_all_vector_stores_by_pattern(name_pattern: str = "OpenAI_challenge_") -> None:
    """
    Delete all vector stores whose names start with the given pattern.
    Useful for cleaning up multiple test runs.
    
    Parameters
    ----------
    name_pattern : str
        Pattern to match vector store names (default: "OpenAI_challenge_")
    """
    stores = client.vector_stores.list()
    matching_stores = [s for s in stores.data if s.name.startswith(name_pattern)]
    
    if not matching_stores:
        print(f"No vector stores found matching pattern '{name_pattern}'")
        return
    
    print(f"Found {len(matching_stores)} vector stores matching '{name_pattern}'")
    for store in matching_stores:
        print(f"\nProcessing: {store.name} (id={store.id})")
        cleanup_vector_store(store.id)

def list_all_files(purpose: Optional[str] = None) -> List:
    """
    List all files in OpenAI storage.
    
    Parameters
    ----------
    purpose : str, optional
        Filter by purpose ('assistants', 'fine-tune', etc.)
        If None, returns all files.
    
    Returns
    -------
    List
        List of file objects
    """
    all_files = []
    
    try:
        # OpenAI's list method might paginate, so we need to handle that
        has_more = True
        after = None
        
        while has_more:
            if after:
                files = client.files.list(purpose=purpose, after=after)
            else:
                files = client.files.list(purpose=purpose) if purpose else client.files.list()
            
            all_files.extend(files.data)
            
            # Check if there are more files
            has_more = files.has_more if hasattr(files, 'has_more') else False
            if has_more and files.data:
                after = files.data[-1].id
            
        return all_files
        
    except Exception as e:
        print(f"❌ Error listing files: {e}")
        return []

def delete_all_files(purpose: Optional[str] = None, dry_run: bool = True) -> dict:
    """
    Delete all files in OpenAI storage.
    
    Parameters
    ----------
    purpose : str, optional
        Only delete files with this purpose ('assistants', 'fine-tune', etc.)
        If None, deletes all files.
    dry_run : bool
        If True, only shows what would be deleted without actually deleting.
    
    Returns
    -------
    dict
        Statistics about the deletion process
    """
    files = list_all_files(purpose=purpose)
    
    if not files:
        print("No files found to delete.")
        return {"total": 0, "deleted": 0, "failed": 0}
    
    stats = {
        "total": len(files),
        "deleted": 0,
        "failed": 0,
        "total_bytes": sum(f.bytes for f in files if hasattr(f, 'bytes') and f.bytes)
    }
    
    print(f"\n{'🔍 DRY RUN - ' if dry_run else ''}Found {stats['total']} files")
    print(f"Total size: {stats['total_bytes'] / (1024*1024):.2f} MB")
    
    if dry_run:
        print("\nFiles that would be deleted:")
        for f in files[:10]:  # Show first 10 files
            created_date = datetime.fromtimestamp(f.created_at).strftime('%Y-%m-%d %H:%M:%S')
            print(f"  - {f.filename} (ID: {f.id}, Purpose: {f.purpose}, Created: {created_date})")
        if len(files) > 10:
            print(f"  ... and {len(files) - 10} more files")
        print("\n⚠️  Run with dry_run=False to actually delete these files")
        return stats
    
    # Actual deletion
    print("\n🗑️  Deleting files...")
    for i, file in enumerate(files):
        try:
            client.files.delete(file.id)
            stats["deleted"] += 1
            print(f"✓ Deleted {file.filename} ({i+1}/{stats['total']})")
            time.sleep(0.1)  # Rate limiting
            
        except Exception as e:
            stats["failed"] += 1
            print(f"❌ Failed to delete {file.filename}: {e}")
    
    print(f"\n✅ Deletion complete!")
    print(f"   Deleted: {stats['deleted']}")
    print(f"   Failed: {stats['failed']}")
    
    return stats

def delete_files_by_name_pattern(pattern: str, dry_run: bool = True) -> dict:
    """
    Delete files whose names contain a specific pattern.
    
    Parameters
    ----------
    pattern : str
        Delete files whose names contain this pattern
    dry_run : bool
        If True, only shows what would be deleted
    
    Returns
    -------
    dict
        Statistics about the deletion process
    """
    all_files = list_all_files()
    matching_files = [f for f in all_files if pattern in f.filename]
    
    if not matching_files:
        print(f"No files found matching pattern '{pattern}'")
        return {"total": 0, "deleted": 0, "failed": 0}
    
    stats = {
        "total": len(matching_files),
        "deleted": 0,
        "failed": 0
    }
    
    print(f"\n{'🔍 DRY RUN - ' if dry_run else ''}Found {stats['total']} files matching '{pattern}'")
    
    if dry_run:
        print("\nFiles that would be deleted:")
        for f in matching_files[:10]:
            print(f"  - {f.filename} (ID: {f.id})")
        if len(matching_files) > 10:
            print(f"  ... and {len(matching_files) - 10} more files")
        print("\n⚠️  Run with dry_run=False to actually delete these files")
        return stats
    
    # Actual deletion
    print("\n🗑️  Deleting matching files...")
    for i, file in enumerate(matching_files):
        try:
            client.files.delete(file.id)
            stats["deleted"] += 1
            print(f"✓ Deleted {file.filename} ({i+1}/{stats['total']})")
            time.sleep(0.1)
            
        except Exception as e:
            stats["failed"] += 1
            print(f"❌ Failed to delete {file.filename}: {e}")
    
    return stats

def show_storage_summary():
    """
    Display a summary of all files in storage grouped by purpose.
    """
    all_files = list_all_files()
    
    if not all_files:
        print("No files in storage.")
        return
    
    # Group by purpose
    by_purpose = {}
    total_size = 0
    
    for f in all_files:
        purpose = f.purpose
        if purpose not in by_purpose:
            by_purpose[purpose] = {"count": 0, "size": 0, "files": []}
        
        by_purpose[purpose]["count"] += 1
        if hasattr(f, 'bytes') and f.bytes:
            by_purpose[purpose]["size"] += f.bytes
            total_size += f.bytes
        by_purpose[purpose]["files"].append(f.filename)
    
    print("\n📊 Storage Summary")
    print("=" * 50)
    print(f"Total files: {len(all_files)}")
    print(f"Total size: {total_size / (1024*1024):.2f} MB")
    print("\nBy purpose:")
    
    for purpose, info in by_purpose.items():
        print(f"\n  {purpose}:")
        print(f"    Count: {info['count']}")
        print(f"    Size: {info['size'] / (1024*1024):.2f} MB")
        print(f"    Files: {', '.join(info['files'][:3])}" + 
              (f" ... and {info['count'] - 3} more" if info['count'] > 3 else ""))
# Out:
# OpenAI_challenge_20250523-082311

# %%
# 1. Get or create vector store
vs_id = get_or_create_vector_store(VECTOR_STORE_NAME)

# 2. Upload and index Documents (skip if already done)
upload_to_vector_store(DIR, vs_id)
# Out:
# Created new vector store 'OpenAI_challenge_20250523-082311' (id=vs_68303070059881918b3f51104fa0bcc0)
# Uploading question_28_openai_gpt-4.1-mini_online_20250522192331.md (5699 bytes)…
# Indexed question_28_openai_gpt-4.1-mini_online_20250522192331.md (file_id=file-G7tR39znZUHi4NEbRkeiCU)
# Uploading question_33_anthropic_claude-3-haiku_online_20250522192802.md (5677 bytes)…
# Indexed question_33_anthropic_claude-3-haiku_online_20250522192802.md (file_id=file-UBR3YzUWpdYLcCgKkaTdvW)
# Uploading question_30_openai_gpt-4.1-mini_online_20250522192511.md (6266 bytes)…
# Indexed question_30_openai_gpt-4.1-mini_online_20250522192511.md (file_id=file-5FwwZHK64yFo5dc46JzSwC)
# Uploading question_5_openai_gpt-4.1-mini_online_20250522190010.md (8708 bytes)…
# Indexed question_5_openai_gpt-4.1-mini_online_20250522190010.md (file_id=file-DieVKu6QKR6SjzaFBsbE9x)
# Uploading question_61_openai_gpt-4.1-mini_online_20250522195723.md (6160 bytes)…
# Indexed question_61_openai_gpt-4.1-mini_online_20250522195723.md (file_id=file-PkbiFjya8VuXfsTSYeukGB)
# Uploading question_21_meta-llama_llama-4-scout_online_20250522191708.md (4987 bytes)…
# Indexed question_21_meta-llama_llama-4-scout_online_20250522191708.md (file_id=file-Cp8nxxdaUPiD1mAPMiYoPG)
# Uploading question_39_anthropic_claude-3-haiku_online_20250522193456.md (5404 bytes)…
# Indexed question_39_anthropic_claude-3-haiku_online_20250522193456.md (file_id=file-Gd5Mfr4sxx7xztLiUTePeG)
# Uploading deep_research_Suspected_Unconfirmed_Sites.md (4121 bytes)…
# Indexed deep_research_Suspected_Unconfirmed_Sites.md (file_id=file-Lt726nWQ3Jdrg2U3rPxhvG)
# Uploading question_41_openai_gpt-4.1-mini_online_20250522193632.md (7486 bytes)…
# Indexed question_41_openai_gpt-4.1-mini_online_20250522193632.md (file_id=file-FMKNRryLr5M81kNsA6seMR)
# Uploading question_55_meta-llama_llama-4-scout_online_20250522195137.md (4915 bytes)…
# Indexed question_55_meta-llama_llama-4-scout_online_20250522195137.md (file_id=file-NGRSjZLdiTout5n24M6fpN)
# Uploading deep_research_Amazonian_Dark_Earths.md (21294 bytes)…
# Indexed deep_research_Amazonian_Dark_Earths.md (file_id=file-95NfARiBmdRmSZumqe1ioq)
# Uploading question_20_anthropic_claude-3-haiku_online_20250522191547.md (3114 bytes)…
# Indexed question_20_anthropic_claude-3-haiku_online_20250522191547.md (file_id=file-7FsxvL1CUG8qunfZa9adYr)
# Uploading question_36_anthropic_claude-3-haiku_online_20250522193132.md (5697 bytes)…
# Indexed question_36_anthropic_claude-3-haiku_online_20250522193132.md (file_id=file-VS4EpdDRdN2CJh12LtPimH)
# Uploading question_69_anthropic_claude-3-haiku_online_20250522200642.md (4725 bytes)…
# Indexed question_69_anthropic_claude-3-haiku_online_20250522200642.md (file_id=file-9JxAQ93anKD8n7hVvYDELy)
# Uploading question_54_openai_gpt-4.1-mini_online_20250522194956.md (7878 bytes)…
# Indexed question_54_openai_gpt-4.1-mini_online_20250522194956.md (file_id=file-UxBkuC1GZGbwRFM3ihBnT5)
# Uploading question_50_anthropic_claude-3-haiku_online_20250522194637.md (4779 bytes)…
# Indexed question_50_anthropic_claude-3-haiku_online_20250522194637.md (file_id=file-W4uY4zouafQgyeXK8mbNRm)
# Uploading question_15_anthropic_claude-3-haiku_online_20250522191050.md (4093 bytes)…
# Indexed question_15_anthropic_claude-3-haiku_online_20250522191050.md (file_id=file-4X8Q4U2fWrCyFb9tuRac7r)
# Uploading question_64_meta-llama_llama-4-scout_online_20250522200130.md (6349 bytes)…
# Indexed question_64_meta-llama_llama-4-scout_online_20250522200130.md (file_id=file-7JUMv8uFpkukj7UZmKUXFr)
# Uploading question_42_meta-llama_llama-4-scout_online_20250522193757.md (4692 bytes)…
# Indexed question_42_meta-llama_llama-4-scout_online_20250522193757.md (file_id=file-SgJxwFCnGfDDrvbrCEUBbw)
# Uploading question_38_openai_gpt-4.1-mini_online_20250522193332.md (6870 bytes)…
# Indexed question_38_openai_gpt-4.1-mini_online_20250522193332.md (file_id=file-3GTHpddQdNXANtw1Kppqeb)
# Uploading question_16_anthropic_claude-3-haiku_online_20250522191155.md (3287 bytes)…
# Indexed question_16_anthropic_claude-3-haiku_online_20250522191155.md (file_id=file-9QTZ57WoAA2NMn1WBZUjgk)
# Uploading question_50_openai_gpt-4.1-mini_online_20250522194621.md (7115 bytes)…
# Indexed question_50_openai_gpt-4.1-mini_online_20250522194621.md (file_id=file-1y86Jcb4WVJk6XdJzkvdmV)
# Uploading question_40_anthropic_claude-3-haiku_online_20250522193549.md (3971 bytes)…
# Indexed question_40_anthropic_claude-3-haiku_online_20250522193549.md (file_id=file-V4uFb5EwFfeF2EQtDT7JFE)
# Uploading question_7_openai_gpt-4.1-mini_online_20250522190220.md (8324 bytes)…
# Indexed question_7_openai_gpt-4.1-mini_online_20250522190220.md (file_id=file-BJUoURzbtTJaFZWJgiRskm)
# Uploading question_46_openai_gpt-4.1-mini_online_20250522194202.md (8939 bytes)…
# Indexed question_46_openai_gpt-4.1-mini_online_20250522194202.md (file_id=file-FQ8pRkvT1z3FUJX1jJeBZn)
# Uploading deep_research_Known_Archaeological_Sites_2.md (7865 bytes)…
# Indexed deep_research_Known_Archaeological_Sites_2.md (file_id=file-GK2xpWLG9zmiEQ96NwjLJP)
# Uploading question_60_anthropic_claude-3-haiku_online_20250522195638.md (5407 bytes)…
# Indexed question_60_anthropic_claude-3-haiku_online_20250522195638.md (file_id=file-PDgKjAd4Hwu5xG222RJpWJ)
# Uploading question_14_anthropic_claude-3-haiku_online_20250522190953.md (2523 bytes)…
# Indexed question_14_anthropic_claude-3-haiku_online_20250522190953.md (file_id=file-3W4dtxP671YGWNA2SYaNDn)
# Uploading question_18_meta-llama_llama-4-scout_online_20250522191402.md (4513 bytes)…
# Indexed question_18_meta-llama_llama-4-scout_online_20250522191402.md (file_id=file-6xseYyDezq2WZ5wB4EyZuS)
# Uploading question_70_anthropic_claude-3-haiku_online_20250522200739.md (4323 bytes)…
# Indexed question_70_anthropic_claude-3-haiku_online_20250522200739.md (file_id=file-75zuueXrykd8fgEus7stGY)
# Uploading question_76_meta-llama_llama-4-scout_online_20250522201519.md (6979 bytes)…
# Indexed question_76_meta-llama_llama-4-scout_online_20250522201519.md (file_id=file-4R8VJeAas1wjtHkLhrQkBq)
# Uploading question_55_anthropic_claude-3-haiku_online_20250522195112.md (5775 bytes)…
# Indexed question_55_anthropic_claude-3-haiku_online_20250522195112.md (file_id=file-JJ8uhSYkdjURwbctta5JeR)
# Uploading question_17_anthropic_claude-3-haiku_online_20250522191243.md (5093 bytes)…
# Indexed question_17_anthropic_claude-3-haiku_online_20250522191243.md (file_id=file-8fKStzSi8r26jfhYaMm825)
# Uploading question_64_anthropic_claude-3-haiku_online_20250522200111.md (6264 bytes)…
# Indexed question_64_anthropic_claude-3-haiku_online_20250522200111.md (file_id=file-27hcdCMvFx2WctE4oW9WgK)
# Uploading question_33_openai_gpt-4.1-mini_online_20250522192747.md (8021 bytes)…
# Indexed question_33_openai_gpt-4.1-mini_online_20250522192747.md (file_id=file-N7JmVa1e2KjyXRe6Df9SCr)
# Uploading question_44_meta-llama_llama-4-scout_online_20250522194011.md (6531 bytes)…
# Indexed question_44_meta-llama_llama-4-scout_online_20250522194011.md (file_id=file-6BCgPMkzgk5eWKts5WFJGd)
# Uploading question_28_meta-llama_llama-4-scout_online_20250522192356.md (3969 bytes)…
# Indexed question_28_meta-llama_llama-4-scout_online_20250522192356.md (file_id=file-S7ogDvgzF6DnfHA6bqKE16)
# Uploading question_22_openai_gpt-4.1-mini_online_20250522191742.md (9555 bytes)…
# Indexed question_22_openai_gpt-4.1-mini_online_20250522191742.md (file_id=file-AMAYmqU9DsMqb4NPcMaXjY)
# Uploading question_66_anthropic_claude-3-haiku_online_20250522200319.md (5113 bytes)…
# Indexed question_66_anthropic_claude-3-haiku_online_20250522200319.md (file_id=file-PuptaP8gDEMe2482kr2z5W)
# Uploading question_60_meta-llama_llama-4-scout_online_20250522195653.md (5489 bytes)…
# Indexed question_60_meta-llama_llama-4-scout_online_20250522195653.md (file_id=file-7rM8UpbpkRcCMCcBsN3Ltc)
# Uploading question_28_anthropic_claude-3-haiku_online_20250522192340.md (2913 bytes)…
# Indexed question_28_anthropic_claude-3-haiku_online_20250522192340.md (file_id=file-2bAFQNoWcpCx5Zkof7txEJ)
# Uploading question_57_meta-llama_llama-4-scout_online_20250522195401.md (4998 bytes)…
# Indexed question_57_meta-llama_llama-4-scout_online_20250522195401.md (file_id=file-MYEEiYCrEsAbthVmWSqwQQ)
# Uploading question_70_openai_gpt-4.1-mini_online_20250522200727.md (6636 bytes)…
# Indexed question_70_openai_gpt-4.1-mini_online_20250522200727.md (file_id=file-XTXV9XiqXQDqwqkYafGAhd)
# Uploading question_63_openai_gpt-4.1-mini_online_20250522195944.md (5253 bytes)…
# Indexed question_63_openai_gpt-4.1-mini_online_20250522195944.md (file_id=file-5Yj7LAU7EoFBRhE2ZUcxfL)
# Uploading question_51_openai_gpt-4.1-mini_online_20250522194712.md (5792 bytes)…
# Indexed question_51_openai_gpt-4.1-mini_online_20250522194712.md (file_id=file-Y8qBnxN9V8kYMdz7TgFoF9)
# Uploading question_10_meta-llama_llama-4-scout_online_20250522190644.md (3388 bytes)…
# Indexed question_10_meta-llama_llama-4-scout_online_20250522190644.md (file_id=file-STXkeXMyH7Kg1PcjwQZgoS)
# Uploading question_17_openai_gpt-4.1-mini_online_20250522191230.md (5352 bytes)…
# Indexed question_17_openai_gpt-4.1-mini_online_20250522191230.md (file_id=file-VbgWtSyt5eq18gzqiDvbqm)
# Uploading question_62_meta-llama_llama-4-scout_online_20250522195914.md (5285 bytes)…
# Indexed question_62_meta-llama_llama-4-scout_online_20250522195914.md (file_id=file-LeZFW52r5XkKn1RKGjDpeh)
# Uploading question_18_openai_gpt-4.1-mini_online_20250522191335.md (6065 bytes)…
# Indexed question_18_openai_gpt-4.1-mini_online_20250522191335.md (file_id=file-Y9MR3jeaVHYWEJ3hiwpK6f)
# Uploading question_1_openai_gpt-4.1-mini_online_20250522185533.md (5867 bytes)…
# Indexed question_1_openai_gpt-4.1-mini_online_20250522185533.md (file_id=file-7Z9vBZCGZxubCodhHL9Tco)
# Uploading question_7_anthropic_claude-3-haiku_online_20250522190233.md (5668 bytes)…
# Indexed question_7_anthropic_claude-3-haiku_online_20250522190233.md (file_id=file-ETP2Ja8jETKoQ6aNR8ChmH)
# Uploading question_62_anthropic_claude-3-haiku_online_20250522195843.md (5312 bytes)…
# Indexed question_62_anthropic_claude-3-haiku_online_20250522195843.md (file_id=file-PQerY99KSmU57zofXZGyPh)
# Uploading question_24_meta-llama_llama-4-scout_online_20250522191955.md (3904 bytes)…
# Indexed question_24_meta-llama_llama-4-scout_online_20250522191955.md (file_id=file-GYYfz5nCYdLk7TrcpWhXpu)
# Uploading question_50_meta-llama_llama-4-scout_online_20250522194651.md (4710 bytes)…
# Indexed question_50_meta-llama_llama-4-scout_online_20250522194651.md (file_id=file-5AQNEkvfk5mc1Ksvkbxuy2)
# Uploading question_65_meta-llama_llama-4-scout_online_20250522200243.md (4449 bytes)…
# Indexed question_65_meta-llama_llama-4-scout_online_20250522200243.md (file_id=file-VqJe3UbMUUzEsnadrXx95H)
# Uploading question_27_openai_gpt-4.1-mini_online_20250522192234.md (7486 bytes)…
# Indexed question_27_openai_gpt-4.1-mini_online_20250522192234.md (file_id=file-WDZjy4g2EyB2aPLSMSRcFd)
# Uploading question_49_meta-llama_llama-4-scout_online_20250522194600.md (5465 bytes)…
# Indexed question_49_meta-llama_llama-4-scout_online_20250522194600.md (file_id=file-1sUnRYe8EcAKnS4VQxsHiR)
# Uploading question_9_anthropic_claude-3-haiku_online_20250522190516.md (2710 bytes)…
# Indexed question_9_anthropic_claude-3-haiku_online_20250522190516.md (file_id=file-AuSAcY3KpAkmtCq5Q8LrV5)
# Uploading deep_research_Known_Archaeological_Sites_3.md (15142 bytes)…
# Indexed deep_research_Known_Archaeological_Sites_3.md (file_id=file-QHxfecBL2vjFn73Uh7gSP2)
# Uploading question_11_openai_gpt-4.1-mini_online_20250522190706.md (5313 bytes)…
# Indexed question_11_openai_gpt-4.1-mini_online_20250522190706.md (file_id=file-Pav4r678ULsfXgUKPdn8Bh)
# Uploading question_3_openai_gpt-4.1-mini_online_20250522185742.md (7251 bytes)…
# Indexed question_3_openai_gpt-4.1-mini_online_20250522185742.md (file_id=file-Ev36BDmiXorF5MHzLpEmxv)
# Uploading question_72_meta-llama_llama-4-scout_online_20250522201039.md (4941 bytes)…
# Indexed question_72_meta-llama_llama-4-scout_online_20250522201039.md (file_id=file-B8iq3NmU56aFVR5Kt3TVAP)
# Uploading question_27_meta-llama_llama-4-scout_online_20250522192301.md (4660 bytes)…
# Indexed question_27_meta-llama_llama-4-scout_online_20250522192301.md (file_id=file-P69RLU7uHVBLj6BZw9mhyx)
# Uploading question_25_meta-llama_llama-4-scout_online_20250522192120.md (3800 bytes)…
# Indexed question_25_meta-llama_llama-4-scout_online_20250522192120.md (file_id=file-GtLgKja7fT2mw5rRxz82Gx)
# Uploading question_48_anthropic_claude-3-haiku_online_20250522194423.md (4604 bytes)…
# Indexed question_48_anthropic_claude-3-haiku_online_20250522194423.md (file_id=file-Wbo7H6CDYTgc2CHaTQuMQc)
# Uploading question_25_anthropic_claude-3-haiku_online_20250522192045.md (4206 bytes)…
# Indexed question_25_anthropic_claude-3-haiku_online_20250522192045.md (file_id=file-HTHCb9X3wwtGuRiGWj8GGm)
# Uploading question_71_openai_gpt-4.1-mini_online_20250522200848.md (8833 bytes)…
# Indexed question_71_openai_gpt-4.1-mini_online_20250522200848.md (file_id=file-DX4XZxk8J51oq8kPLPqndq)
# Uploading question_25_openai_gpt-4.1-mini_online_20250522192024.md (6724 bytes)…
# Indexed question_25_openai_gpt-4.1-mini_online_20250522192024.md (file_id=file-RGsEq1VTod8L46DW3LkwSs)
# Uploading question_67_meta-llama_llama-4-scout_online_20250522200429.md (4579 bytes)…
# Indexed question_67_meta-llama_llama-4-scout_online_20250522200429.md (file_id=file-NydnXBx3wC2SWp1jek6Yyw)
# Uploading question_53_openai_gpt-4.1-mini_online_20250522194903.md (7362 bytes)…
# Indexed question_53_openai_gpt-4.1-mini_online_20250522194903.md (file_id=file-UpHur9Tbeo9q4t7y7kV6E3)
# Uploading question_13_openai_gpt-4.1-mini_online_20250522190856.md (6878 bytes)…
# Indexed question_13_openai_gpt-4.1-mini_online_20250522190856.md (file_id=file-QyaUQnYgxWhRX8sDFiVH8i)
# Uploading question_7_meta-llama_llama-4-scout_online_20250522190258.md (4441 bytes)…
# Indexed question_7_meta-llama_llama-4-scout_online_20250522190258.md (file_id=file-SU3XahJNbdqpRPNax8YbyV)
# Uploading question_36_openai_gpt-4.1-mini_online_20250522193117.md (9452 bytes)…
# Indexed question_36_openai_gpt-4.1-mini_online_20250522193117.md (file_id=file-6Fe9JvpehU8V7YMPpoTgMP)
# Uploading question_58_openai_gpt-4.1-mini_online_20250522195423.md (5673 bytes)…
# Indexed question_58_openai_gpt-4.1-mini_online_20250522195423.md (file_id=file-WvMAfRqsLhCbyqEgbtxeVQ)
# Uploading question_33_meta-llama_llama-4-scout_online_20250522192837.md (6469 bytes)…
# Indexed question_33_meta-llama_llama-4-scout_online_20250522192837.md (file_id=file-YVTxDARiH5nbaZUvajerq1)
# Uploading question_48_openai_gpt-4.1-mini_online_20250522194410.md (5954 bytes)…
# Indexed question_48_openai_gpt-4.1-mini_online_20250522194410.md (file_id=file-TjfLbgvTvyzurxqBRf6Hjg)
# Uploading question_31_anthropic_claude-3-haiku_online_20250522192611.md (4719 bytes)…
# Indexed question_31_anthropic_claude-3-haiku_online_20250522192611.md (file_id=file-9AZTf3KLYhRqm8BY1GFuV8)
# Uploading question_54_anthropic_claude-3-haiku_online_20250522195010.md (5282 bytes)…
# Indexed question_54_anthropic_claude-3-haiku_online_20250522195010.md (file_id=file-EL6YLxhRd5EKeGaJLwjGjd)
# Uploading question_52_meta-llama_llama-4-scout_online_20250522194833.md (6504 bytes)…
# Indexed question_52_meta-llama_llama-4-scout_online_20250522194833.md (file_id=file-DzdHqGVxZtLa12sf1AMNCR)
# Uploading question_20_openai_gpt-4.1-mini_online_20250522191537.md (5211 bytes)…
# Indexed question_20_openai_gpt-4.1-mini_online_20250522191537.md (file_id=file-1x7gk6CtMFPrPahudXwLxz)
# Uploading question_19_anthropic_claude-3-haiku_online_20250522191447.md (4443 bytes)…
# Indexed question_19_anthropic_claude-3-haiku_online_20250522191447.md (file_id=file-6obCrVdK7vZKCEwFPUthjr)
# Uploading question_35_meta-llama_llama-4-scout_online_20250522193036.md (5105 bytes)…
# Indexed question_35_meta-llama_llama-4-scout_online_20250522193036.md (file_id=file-8XwPpkHWCKPivaCjHNLs5u)
# Uploading deep_research_Machine_Learning_Models_2.md (18481 bytes)…
# Indexed deep_research_Machine_Learning_Models_2.md (file_id=file-9zWLFThxu5Re65o2bTWuS6)
# Uploading question_66_openai_gpt-4.1-mini_online_20250522200306.md (6031 bytes)…
# Indexed question_66_openai_gpt-4.1-mini_online_20250522200306.md (file_id=file-MhJJqdmaTRGAeoj4pU9wfv)
# Uploading question_61_anthropic_claude-3-haiku_online_20250522195736.md (5443 bytes)…
# Indexed question_61_anthropic_claude-3-haiku_online_20250522195736.md (file_id=file-2j8VcvsQHMUkysVocff9YX)
# Uploading question_39_openai_gpt-4.1-mini_online_20250522193441.md (6579 bytes)…
# Indexed question_39_openai_gpt-4.1-mini_online_20250522193441.md (file_id=file-A7F1QK7vZoJWAFaHrj2weK)
# Uploading question_3_meta-llama_llama-4-scout_online_20250522185813.md (5951 bytes)…
# Indexed question_3_meta-llama_llama-4-scout_online_20250522185813.md (file_id=file-EvL6qThBjXr7mfVSxAt15x)
# Uploading deep_research_Likely_Locations_of_Archaeological.md (27166 bytes)…
# Indexed deep_research_Likely_Locations_of_Archaeological.md (file_id=file-QBiWyybWvxgZ75gf9FeskD)
# Uploading question_5_meta-llama_llama-4-scout_online_20250522190051.md (5731 bytes)…
# Indexed question_5_meta-llama_llama-4-scout_online_20250522190051.md (file_id=file-2wBV8cbeJWNmzZgsAtNT33)
# Uploading question_60_openai_gpt-4.1-mini_online_20250522195625.md (6519 bytes)…
# Indexed question_60_openai_gpt-4.1-mini_online_20250522195625.md (file_id=file-LHfe99nLH8cmPWdC4skKNf)
# Uploading question_47_openai_gpt-4.1-mini_online_20250522194259.md (8396 bytes)…
# Indexed question_47_openai_gpt-4.1-mini_online_20250522194259.md (file_id=file-P8Y1nNi6wcNNWzJsad5ZrB)
# Uploading question_75_openai_gpt-4.1-mini_online_20250522201330.md (6302 bytes)…
# Indexed question_75_openai_gpt-4.1-mini_online_20250522201330.md (file_id=file-Hy24ZPibhWdnUPTUJ1QwvR)
# Uploading question_6_meta-llama_llama-4-scout_online_20250522190157.md (5040 bytes)…
# Indexed question_6_meta-llama_llama-4-scout_online_20250522190157.md (file_id=file-AUR95y3m9AUPAeD6CU8vAD)
# Uploading question_19_meta-llama_llama-4-scout_online_20250522191518.md (4907 bytes)…
# Indexed question_19_meta-llama_llama-4-scout_online_20250522191518.md (file_id=file-Ncwzwu7ugbqVKHyvEPKGrR)
# Uploading question_72_openai_gpt-4.1-mini_online_20250522201000.md (7705 bytes)…
# Indexed question_72_openai_gpt-4.1-mini_online_20250522201000.md (file_id=file-BACwS6cKantQADaxYLbrAQ)
# Uploading question_64_openai_gpt-4.1-mini_online_20250522200056.md (8572 bytes)…
# Indexed question_64_openai_gpt-4.1-mini_online_20250522200056.md (file_id=file-6BUyfyZETbDPkonQoJgMRN)
# Uploading question_34_anthropic_claude-3-haiku_online_20250522192917.md (2329 bytes)…
# Indexed question_34_anthropic_claude-3-haiku_online_20250522192917.md (file_id=file-7jSr4E3MJhft4PZLrFomEh)
# Uploading question_58_meta-llama_llama-4-scout_online_20250522195502.md (4740 bytes)…
# Indexed question_58_meta-llama_llama-4-scout_online_20250522195502.md (file_id=file-KkcckMFaRyEF3unsTAKL5x)
# Uploading question_39_meta-llama_llama-4-scout_online_20250522193510.md (4613 bytes)…
# Indexed question_39_meta-llama_llama-4-scout_online_20250522193510.md (file_id=file-XHypBfMMZtjqiqLBvmDNhc)
# Uploading question_2_anthropic_claude-3-haiku_online_20250522185649.md (6521 bytes)…
# Indexed question_2_anthropic_claude-3-haiku_online_20250522185649.md (file_id=file-EacJLwhvbEHFR1WCUWGazP)
# Uploading question_59_meta-llama_llama-4-scout_online_20250522195604.md (4676 bytes)…
# Indexed question_59_meta-llama_llama-4-scout_online_20250522195604.md (file_id=file-2Y2i3V1pKBZnmQi5WxHYJE)
# Uploading question_63_meta-llama_llama-4-scout_online_20250522200016.md (3540 bytes)…
# Indexed question_63_meta-llama_llama-4-scout_online_20250522200016.md (file_id=file-NxuZfttW9Z8ydjqxsRyj7w)
# Uploading question_8_anthropic_claude-3-haiku_online_20250522190359.md (3649 bytes)…
# Indexed question_8_anthropic_claude-3-haiku_online_20250522190359.md (file_id=file-3QGTUSxe74rr38mtwh7UJA)
# Uploading question_34_meta-llama_llama-4-scout_online_20250522192936.md (5676 bytes)…
# Indexed question_34_meta-llama_llama-4-scout_online_20250522192936.md (file_id=file-3u9Rqv9ie3Cpnh8edVBDFu)
# Uploading question_24_anthropic_claude-3-haiku_online_20250522191941.md (4749 bytes)…
# Indexed question_24_anthropic_claude-3-haiku_online_20250522191941.md (file_id=file-JvX8Bsj8Y3aPfhC8Y2fvRU)
# Uploading question_1_anthropic_claude-3-haiku_online_20250522185546.md (4892 bytes)…
# Indexed question_1_anthropic_claude-3-haiku_online_20250522185546.md (file_id=file-HqqNzktEw9BhmzVePribq5)
# Uploading question_23_openai_gpt-4.1-mini_online_20250522191835.md (6274 bytes)…
# Indexed question_23_openai_gpt-4.1-mini_online_20250522191835.md (file_id=file-B7CZhsZ4FtHkf9WiSB3tp3)
# Uploading question_65_anthropic_claude-3-haiku_online_20250522200217.md (7082 bytes)…
# Indexed question_65_anthropic_claude-3-haiku_online_20250522200217.md (file_id=file-6FcFKS1hrT5DvMLn6wYzS7)
# Uploading question_38_meta-llama_llama-4-scout_online_20250522193414.md (5450 bytes)…
# Indexed question_38_meta-llama_llama-4-scout_online_20250522193414.md (file_id=file-BtEpKprF4Td31qx2d95BgK)
# Uploading question_26_meta-llama_llama-4-scout_online_20250522192213.md (4350 bytes)…
# Indexed question_26_meta-llama_llama-4-scout_online_20250522192213.md (file_id=file-2fj5UmNmDvmPLtAWsRcTw1)
# Uploading question_61_meta-llama_llama-4-scout_online_20250522195749.md (4116 bytes)…
# Indexed question_61_meta-llama_llama-4-scout_online_20250522195749.md (file_id=file-NnrpxwUNADaGvpixcs4zNU)
# Uploading question_40_openai_gpt-4.1-mini_online_20250522193538.md (6698 bytes)…
# Indexed question_40_openai_gpt-4.1-mini_online_20250522193538.md (file_id=file-EsMsumkUVfaJw2vPL5hFuW)
# Uploading question_19_openai_gpt-4.1-mini_online_20250522191434.md (7549 bytes)…
# Indexed question_19_openai_gpt-4.1-mini_online_20250522191434.md (file_id=file-MADuUty38FYFGLYyB6wwAw)
# Uploading question_56_meta-llama_llama-4-scout_online_20250522195241.md (4398 bytes)…
# Indexed question_56_meta-llama_llama-4-scout_online_20250522195241.md (file_id=file-Rduadr5Y9W8kGtHEo4AMHU)
# Uploading question_4_openai_gpt-4.1-mini_online_20250522185853.md (8025 bytes)…
# Indexed question_4_openai_gpt-4.1-mini_online_20250522185853.md (file_id=file-6u11X6DiFWKtzcQJmhkNTX)
# Uploading question_47_meta-llama_llama-4-scout_online_20250522194342.md (5651 bytes)…
# Indexed question_47_meta-llama_llama-4-scout_online_20250522194342.md (file_id=file-4XSaRg9qtnwAqd3pgRub7J)
# Uploading question_18_anthropic_claude-3-haiku_online_20250522191347.md (4610 bytes)…
# Indexed question_18_anthropic_claude-3-haiku_online_20250522191347.md (file_id=file-T7LKNZqrVrxPCqQEYngRNs)
# Uploading question_9_openai_gpt-4.1-mini_online_20250522190505.md (5039 bytes)…
# Indexed question_9_openai_gpt-4.1-mini_online_20250522190505.md (file_id=file-PGPERS6gK2pFRLHdca8h4V)
# Uploading question_72_anthropic_claude-3-haiku_online_20250522201015.md (6662 bytes)…
# Indexed question_72_anthropic_claude-3-haiku_online_20250522201015.md (file_id=file-CmftzNDyVZPxYeDs5gCDSJ)
# Uploading question_45_openai_gpt-4.1-mini_online_20250522194046.md (8820 bytes)…
# Indexed question_45_openai_gpt-4.1-mini_online_20250522194046.md (file_id=file-XwwwVsdTD8bMuVPZ7LkGmZ)
# Uploading question_29_openai_gpt-4.1-mini_online_20250522192419.md (4630 bytes)…
# Indexed question_29_openai_gpt-4.1-mini_online_20250522192419.md (file_id=file-UkhGBXB2Qt5JCXHmyJJ28c)
# Uploading question_48_meta-llama_llama-4-scout_online_20250522194456.md (4211 bytes)…
# Indexed question_48_meta-llama_llama-4-scout_online_20250522194456.md (file_id=file-BdWQu3etdD2cqWzjGr9xJP)
# Uploading question_43_anthropic_claude-3-haiku_online_20250522193852.md (6532 bytes)…
# Indexed question_43_anthropic_claude-3-haiku_online_20250522193852.md (file_id=file-GuQySVWoccmdJNbcMu7okJ)
# Uploading question_27_anthropic_claude-3-haiku_online_20250522192247.md (4610 bytes)…
# Indexed question_27_anthropic_claude-3-haiku_online_20250522192247.md (file_id=file-DR2Ce3cpX7D8F7oHD7WuZ4)
# Uploading question_12_openai_gpt-4.1-mini_online_20250522190759.md (6350 bytes)…
# Indexed question_12_openai_gpt-4.1-mini_online_20250522190759.md (file_id=file-1pUzBbaDo1WEqvsGRqMGZU)
# Uploading question_74_openai_gpt-4.1-mini_online_20250522201227.md (7602 bytes)…
# Indexed question_74_openai_gpt-4.1-mini_online_20250522201227.md (file_id=file-9dBuh3HS3a7pP3zwQsGudB)
# Uploading question_20_meta-llama_llama-4-scout_online_20250522191603.md (4234 bytes)…
# Indexed question_20_meta-llama_llama-4-scout_online_20250522191603.md (file_id=file-2iaNWg82RQ15Ei7BwFk69q)
# Uploading question_2_meta-llama_llama-4-scout_online_20250522185705.md (5715 bytes)…
# Indexed question_2_meta-llama_llama-4-scout_online_20250522185705.md (file_id=file-MT5EhXNbBiwkSzkB8srWrn)
# Uploading question_26_openai_gpt-4.1-mini_online_20250522192145.md (6975 bytes)…
# Indexed question_26_openai_gpt-4.1-mini_online_20250522192145.md (file_id=file-5qa4T5uGENJ7BPCfkDBCCp)
# Uploading question_74_anthropic_claude-3-haiku_online_20250522201242.md (6501 bytes)…
# Indexed question_74_anthropic_claude-3-haiku_online_20250522201242.md (file_id=file-BvhqE8ucz5jsGDm4J9sLuY)
# Uploading question_57_openai_gpt-4.1-mini_online_20250522195315.md (7712 bytes)…
# Indexed question_57_openai_gpt-4.1-mini_online_20250522195315.md (file_id=file-TdDzHsPhZKXhKGuvCEujHt)
# Uploading question_35_anthropic_claude-3-haiku_online_20250522193015.md (4487 bytes)…
# Indexed question_35_anthropic_claude-3-haiku_online_20250522193015.md (file_id=file-MRE89rfdr3qcQPKsmJzLQE)
# Uploading question_23_meta-llama_llama-4-scout_online_20250522191901.md (4081 bytes)…
# Indexed question_23_meta-llama_llama-4-scout_online_20250522191901.md (file_id=file-6zeMpY8bQuCN8A2v5fxXHv)
# Uploading question_1_meta-llama_llama-4-scout_online_20250522185601.md (4887 bytes)…
# Indexed question_1_meta-llama_llama-4-scout_online_20250522185601.md (file_id=file-6CZEHxUsPNhigyvC48dYoz)
# Uploading question_36_meta-llama_llama-4-scout_online_20250522193143.md (4288 bytes)…
# Indexed question_36_meta-llama_llama-4-scout_online_20250522193143.md (file_id=file-DXjU25jPSAfscDJBZYm6NG)
# Uploading question_8_openai_gpt-4.1-mini_online_20250522190346.md (8195 bytes)…
# Indexed question_8_openai_gpt-4.1-mini_online_20250522190346.md (file_id=file-2EebQPM5sgHsxNXKTqoezw)
# Uploading question_6_openai_gpt-4.1-mini_online_20250522190126.md (7060 bytes)…
# Indexed question_6_openai_gpt-4.1-mini_online_20250522190126.md (file_id=file-8LfoLPWxen1SQgTYQUNJnv)
# Uploading question_44_openai_gpt-4.1-mini_online_20250522193937.md (7132 bytes)…
# Indexed question_44_openai_gpt-4.1-mini_online_20250522193937.md (file_id=file-KoiiwNaWuGT2GyHpd99MQS)
# Uploading question_37_meta-llama_llama-4-scout_online_20250522193306.md (4091 bytes)…
# Indexed question_37_meta-llama_llama-4-scout_online_20250522193306.md (file_id=file-LPm9W6SR7Y8oaqJNvHQ6gx)
# Uploading question_43_meta-llama_llama-4-scout_online_20250522193907.md (6163 bytes)…
# Indexed question_43_meta-llama_llama-4-scout_online_20250522193907.md (file_id=file-CNenBwtB3vz3Gw92p1iP7c)
# Uploading question_69_openai_gpt-4.1-mini_online_20250522200628.md (6716 bytes)…
# Indexed question_69_openai_gpt-4.1-mini_online_20250522200628.md (file_id=file-RMQqmPCahqWazhdWPHJKRD)
# Uploading question_32_anthropic_claude-3-haiku_online_20250522192708.md (5087 bytes)…
# Indexed question_32_anthropic_claude-3-haiku_online_20250522192708.md (file_id=file-4mBovVe5GuWmfoxvm25enw)
# Uploading question_11_anthropic_claude-3-haiku_online_20250522190717.md (3742 bytes)…
# Indexed question_11_anthropic_claude-3-haiku_online_20250522190717.md (file_id=file-2YkD5D7rd5Cv4cZ2sESTGo)
# Uploading deep_research_Detecting_Archaeological_Sites_SOTA.md (27393 bytes)…
# Indexed deep_research_Detecting_Archaeological_Sites_SOTA.md (file_id=file-DBduVcwduH53MyertLzuQJ)
# Uploading question_54_meta-llama_llama-4-scout_online_20250522195037.md (4649 bytes)…
# Indexed question_54_meta-llama_llama-4-scout_online_20250522195037.md (file_id=file-9iRMPcpQUQhUDsD9cCZPra)
# Uploading question_56_anthropic_claude-3-haiku_online_20250522195214.md (4066 bytes)…
# Indexed question_56_anthropic_claude-3-haiku_online_20250522195214.md (file_id=file-LoiwYV79Ski5Z5Sh4isgkL)
# Uploading question_21_openai_gpt-4.1-mini_online_20250522191638.md (8149 bytes)…
# Indexed question_21_openai_gpt-4.1-mini_online_20250522191638.md (file_id=file-B2oYA1A6GH8Mhu7YW4K92T)
# Uploading question_58_anthropic_claude-3-haiku_online_20250522195436.md (4835 bytes)…
# Indexed question_58_anthropic_claude-3-haiku_online_20250522195436.md (file_id=file-J5YfH9gN4tqYpR8ZGcjZjz)
# Uploading question_47_anthropic_claude-3-haiku_online_20250522194321.md (7380 bytes)…
# Indexed question_47_anthropic_claude-3-haiku_online_20250522194321.md (file_id=file-52fp1vfpLXad6GrWHqTSma)
# Uploading question_73_openai_gpt-4.1-mini_online_20250522201116.md (7941 bytes)…
# Indexed question_73_openai_gpt-4.1-mini_online_20250522201116.md (file_id=file-J3yk5pvckUhM3fSXirk33b)
# Uploading question_45_anthropic_claude-3-haiku_online_20250522194058.md (4618 bytes)…
# Indexed question_45_anthropic_claude-3-haiku_online_20250522194058.md (file_id=file-MWpBTqcCboFE3tHfpg1ZWh)
# Uploading question_23_anthropic_claude-3-haiku_online_20250522191849.md (5110 bytes)…
# Indexed question_23_anthropic_claude-3-haiku_online_20250522191849.md (file_id=file-NpsU56aLCYq3Mm5pW7xwAr)
# Uploading question_10_openai_gpt-4.1-mini_online_20250522190606.md (6311 bytes)…
# Indexed question_10_openai_gpt-4.1-mini_online_20250522190606.md (file_id=file-QyG8saWNL6cnnr469kjG8P)
# Uploading question_24_openai_gpt-4.1-mini_online_20250522191929.md (7078 bytes)…
# Indexed question_24_openai_gpt-4.1-mini_online_20250522191929.md (file_id=file-KhgZekLD1WsQynTkqtNeRF)
# Uploading question_12_meta-llama_llama-4-scout_online_20250522190829.md (4418 bytes)…
# Indexed question_12_meta-llama_llama-4-scout_online_20250522190829.md (file_id=file-PLbdYHm5iWBTGxXJ9FSFoj)
# Uploading question_71_meta-llama_llama-4-scout_online_20250522200931.md (6409 bytes)…
# Indexed question_71_meta-llama_llama-4-scout_online_20250522200931.md (file_id=file-TtqQyE2xFZ1HNNVqiE2H1t)
# Uploading question_75_anthropic_claude-3-haiku_online_20250522201344.md (5769 bytes)…
# Indexed question_75_anthropic_claude-3-haiku_online_20250522201344.md (file_id=file-AW8JmGp4FCVJqdYXNPaPR5)
# Uploading deep_research_Machine_Learning_Models.md (12271 bytes)…
# Indexed deep_research_Machine_Learning_Models.md (file_id=file-BPegWq3gYRTj6kVckR5pYw)
# Uploading question_22_anthropic_claude-3-haiku_online_20250522191753.md (3455 bytes)…
# Indexed question_22_anthropic_claude-3-haiku_online_20250522191753.md (file_id=file-XHmQfuWTBHVCTxwGYNVS5b)
# Uploading question_76_openai_gpt-4.1-mini_online_20250522201429.md (9453 bytes)…
# Indexed question_76_openai_gpt-4.1-mini_online_20250522201429.md (file_id=file-3fhmZ82v9ciyd5fcKYwHYS)
# Uploading question_46_meta-llama_llama-4-scout_online_20250522194230.md (5286 bytes)…
# Indexed question_46_meta-llama_llama-4-scout_online_20250522194230.md (file_id=file-J5nbauFEjum2xfRAD4xSwL)
# Uploading question_14_openai_gpt-4.1-mini_online_20250522190943.md (5638 bytes)…
# Indexed question_14_openai_gpt-4.1-mini_online_20250522190943.md (file_id=file-LsXoQgPRi9DzzvtzsomueZ)
# Uploading question_37_anthropic_claude-3-haiku_online_20250522193227.md (3475 bytes)…
# Indexed question_37_anthropic_claude-3-haiku_online_20250522193227.md (file_id=file-PNLtbx9bzLsDbd8BZZWCq6)
# Uploading question_46_anthropic_claude-3-haiku_online_20250522194215.md (4931 bytes)…
# Indexed question_46_anthropic_claude-3-haiku_online_20250522194215.md (file_id=file-HbEUN146V6V9CANV69rDuf)
# Uploading question_42_anthropic_claude-3-haiku_online_20250522193744.md (6097 bytes)…
# Indexed question_42_anthropic_claude-3-haiku_online_20250522193744.md (file_id=file-5BESh3KN3ahvG7cQGmWBsY)
# Uploading question_12_anthropic_claude-3-haiku_online_20250522190814.md (4331 bytes)…
# Indexed question_12_anthropic_claude-3-haiku_online_20250522190814.md (file_id=file-9auVQYyFsYs6c2hRbun77L)
# Uploading question_67_openai_gpt-4.1-mini_online_20250522200401.md (7199 bytes)…
# Indexed question_67_openai_gpt-4.1-mini_online_20250522200401.md (file_id=file-3LHxKucUtLCdHNypiRWg6T)
# Uploading question_21_anthropic_claude-3-haiku_online_20250522191653.md (5337 bytes)…
# Indexed question_21_anthropic_claude-3-haiku_online_20250522191653.md (file_id=file-VcWtb9faSgYB8E2kVdZ1Cf)
# Uploading deep_research_Known_Archaeological_Sites.md (10256 bytes)…
# Indexed deep_research_Known_Archaeological_Sites.md (file_id=file-KKKT38PfMv5rmSQf81Mj1q)
# Uploading question_55_openai_gpt-4.1-mini_online_20250522195059.md (6262 bytes)…
# Indexed question_55_openai_gpt-4.1-mini_online_20250522195059.md (file_id=file-1SxHE3v2qMrte8QLF1ossV)
# Uploading question_31_meta-llama_llama-4-scout_online_20250522192622.md (4586 bytes)…
# Indexed question_31_meta-llama_llama-4-scout_online_20250522192622.md (file_id=file-CzJYKgj9reJdf88gYoEXG5)
# Uploading question_14_meta-llama_llama-4-scout_online_20250522191007.md (2977 bytes)…
# Indexed question_14_meta-llama_llama-4-scout_online_20250522191007.md (file_id=file-NaJc7127dw15xSmqi6UUjD)
# Uploading question_13_meta-llama_llama-4-scout_online_20250522190921.md (3679 bytes)…
# Indexed question_13_meta-llama_llama-4-scout_online_20250522190921.md (file_id=file-KXphSBu2ocsQTPSoXZVPfm)
# Uploading question_4_meta-llama_llama-4-scout_online_20250522185926.md (4709 bytes)…
# Indexed question_4_meta-llama_llama-4-scout_online_20250522185926.md (file_id=file-7p6PanHfyCdN6zTMDv9WSy)
# Uploading question_29_anthropic_claude-3-haiku_online_20250522192430.md (3051 bytes)…
# Indexed question_29_anthropic_claude-3-haiku_online_20250522192430.md (file_id=file-H6d9iJ8tdAEhpTnZb8NcDC)
# Uploading question_22_meta-llama_llama-4-scout_online_20250522191809.md (5017 bytes)…
# Indexed question_22_meta-llama_llama-4-scout_online_20250522191809.md (file_id=file-AyqBWRJ4ogUte9X99bLgdj)
# Uploading question_68_meta-llama_llama-4-scout_online_20250522200600.md (5481 bytes)…
# Indexed question_68_meta-llama_llama-4-scout_online_20250522200600.md (file_id=file-MLqW6fgWk8ySuJF4kgdp9x)
# Uploading question_59_anthropic_claude-3-haiku_online_20250522195542.md (5204 bytes)…
# Indexed question_59_anthropic_claude-3-haiku_online_20250522195542.md (file_id=file-8baeNn1zon7GTKsbDAJRjK)
# Uploading question_56_openai_gpt-4.1-mini_online_20250522195202.md (7155 bytes)…
# Indexed question_56_openai_gpt-4.1-mini_online_20250522195202.md (file_id=file-FsbxqCXkkGhgmSccqsFkSE)
# Uploading question_32_meta-llama_llama-4-scout_online_20250522192721.md (4254 bytes)…
# Indexed question_32_meta-llama_llama-4-scout_online_20250522192721.md (file_id=file-Ma1cxcdBD1oYH2XbR4L1m3)
# Uploading question_15_meta-llama_llama-4-scout_online_20250522191059.md (3019 bytes)…
# Indexed question_15_meta-llama_llama-4-scout_online_20250522191059.md (file_id=file-FEcXaByxCgizDAjTAXUArj)
# Uploading question_38_anthropic_claude-3-haiku_online_20250522193348.md (5661 bytes)…
# Indexed question_38_anthropic_claude-3-haiku_online_20250522193348.md (file_id=file-XvXoEBcbBXMkCwQQtEb8NU)
# Uploading question_30_anthropic_claude-3-haiku_online_20250522192528.md (5625 bytes)…
# Indexed question_30_anthropic_claude-3-haiku_online_20250522192528.md (file_id=file-CLAyDPeNXuhXRRVnY5upoW)
# Uploading question_53_meta-llama_llama-4-scout_online_20250522194924.md (4339 bytes)…
# Indexed question_53_meta-llama_llama-4-scout_online_20250522194924.md (file_id=file-HoiS86AhBSQrvhkWXYKsPv)
# Uploading question_74_meta-llama_llama-4-scout_online_20250522201303.md (5710 bytes)…
# Indexed question_74_meta-llama_llama-4-scout_online_20250522201303.md (file_id=file-Ma3MvNAuAUhtfBw5ukq5AB)
# Uploading question_2_openai_gpt-4.1-mini_online_20250522185633.md (8173 bytes)…
# Indexed question_2_openai_gpt-4.1-mini_online_20250522185633.md (file_id=file-Uv7iDMMzv94rdfGRPCafuS)
# Uploading question_44_anthropic_claude-3-haiku_online_20250522193954.md (6503 bytes)…
# Indexed question_44_anthropic_claude-3-haiku_online_20250522193954.md (file_id=file-XKyAhWapp5akSaxFAjRyMk)
# Uploading question_6_anthropic_claude-3-haiku_online_20250522190141.md (5607 bytes)…
# Indexed question_6_anthropic_claude-3-haiku_online_20250522190141.md (file_id=file-Ed9JPjywNMS16ZFqnWU7KB)
# Uploading question_49_openai_gpt-4.1-mini_online_20250522194524.md (7545 bytes)…
# Indexed question_49_openai_gpt-4.1-mini_online_20250522194524.md (file_id=file-DowTxSRgHyMqRrFnP5mSQr)
# Uploading question_45_meta-llama_llama-4-scout_online_20250522194133.md (6290 bytes)…
# Indexed question_45_meta-llama_llama-4-scout_online_20250522194133.md (file_id=file-YPrM4X6QZPBwymDGQ3HdiR)
# Uploading question_51_meta-llama_llama-4-scout_online_20250522194735.md (3841 bytes)…
# Indexed question_51_meta-llama_llama-4-scout_online_20250522194735.md (file_id=file-KLNbdTNGxei7gfAvH4xoR2)
# Uploading question_11_meta-llama_llama-4-scout_online_20250522190732.md (4412 bytes)…
# Indexed question_11_meta-llama_llama-4-scout_online_20250522190732.md (file_id=file-XnPWynNWA498P2aAEsCtn7)
# Uploading question_8_meta-llama_llama-4-scout_online_20250522190438.md (4988 bytes)…
# Indexed question_8_meta-llama_llama-4-scout_online_20250522190438.md (file_id=file-PFbTacPfmU6Zjf7MDeHbuY)
# Uploading question_42_openai_gpt-4.1-mini_online_20250522193728.md (9365 bytes)…
# Indexed question_42_openai_gpt-4.1-mini_online_20250522193728.md (file_id=file-8dyB9g75x7tRDgf71gk16Z)
# Uploading question_29_meta-llama_llama-4-scout_online_20250522192445.md (3082 bytes)…
# Indexed question_29_meta-llama_llama-4-scout_online_20250522192445.md (file_id=file-8tdvmP2sd9S3mcvKPbhn4u)
# Uploading question_73_anthropic_claude-3-haiku_online_20250522201129.md (5290 bytes)…
# Indexed question_73_anthropic_claude-3-haiku_online_20250522201129.md (file_id=file-VWKFkansLxJa8pcjyQ5spJ)
# Uploading question_53_anthropic_claude-3-haiku_online_20250522194916.md (5890 bytes)…
# Indexed question_53_anthropic_claude-3-haiku_online_20250522194916.md (file_id=file-MadMPyaDxsQdCg72pofeN1)
# Uploading question_65_openai_gpt-4.1-mini_online_20250522200200.md (7376 bytes)…
# Indexed question_65_openai_gpt-4.1-mini_online_20250522200200.md (file_id=file-8jFV9oUPTiJfiViftNqeFb)
# Uploading question_76_anthropic_claude-3-haiku_online_20250522201445.md (5982 bytes)…
# Indexed question_76_anthropic_claude-3-haiku_online_20250522201445.md (file_id=file-4gojCwbvDneeW3krjwWJgQ)
# Uploading question_9_meta-llama_llama-4-scout_online_20250522190530.md (3673 bytes)…
# Indexed question_9_meta-llama_llama-4-scout_online_20250522190530.md (file_id=file-LVpynefDj1b6EtpMRWLkfH)
# Uploading question_67_anthropic_claude-3-haiku_online_20250522200414.md (5480 bytes)…
# Indexed question_67_anthropic_claude-3-haiku_online_20250522200414.md (file_id=file-1w1V2r2cBL7L76e8vAqg7v)
# Uploading question_17_meta-llama_llama-4-scout_online_20250522191312.md (3817 bytes)…
# Indexed question_17_meta-llama_llama-4-scout_online_20250522191312.md (file_id=file-4qWyj62AdeY2fFXzLKoT8u)
# Uploading question_69_meta-llama_llama-4-scout_online_20250522200658.md (5567 bytes)…
# Indexed question_69_meta-llama_llama-4-scout_online_20250522200658.md (file_id=file-QDw6JKiu8V1Nm8iFFmUX3A)
# Uploading question_51_anthropic_claude-3-haiku_online_20250522194723.md (3852 bytes)…
# Indexed question_51_anthropic_claude-3-haiku_online_20250522194723.md (file_id=file-HVjTpYdHhk9uL9Cf89wbN7)
# Uploading question_3_anthropic_claude-3-haiku_online_20250522185757.md (4873 bytes)…
# Indexed question_3_anthropic_claude-3-haiku_online_20250522185757.md (file_id=file-6DjqN9F9WF3DYaLLPs1X5Y)
# Uploading question_5_anthropic_claude-3-haiku_online_20250522190025.md (6050 bytes)…
# Indexed question_5_anthropic_claude-3-haiku_online_20250522190025.md (file_id=file-Lo5tan7YZQ2TQPh4z1u2sv)
# Uploading question_43_openai_gpt-4.1-mini_online_20250522193837.md (11142 bytes)…
# Indexed question_43_openai_gpt-4.1-mini_online_20250522193837.md (file_id=file-1hgm8biuLCfvxfGQWPimi3)
# Uploading question_57_anthropic_claude-3-haiku_online_20250522195333.md (8224 bytes)…
# Indexed question_57_anthropic_claude-3-haiku_online_20250522195333.md (file_id=file-UoaWetA9MtKy7aS4e6Vq4P)
# Uploading deep_research_Effectiveness_of_LIDAR.md (12672 bytes)…
# Indexed deep_research_Effectiveness_of_LIDAR.md (file_id=file-TLi6w4S6kHb5MRdvJJGGrN)
# Uploading question_4_anthropic_claude-3-haiku_online_20250522185908.md (5482 bytes)…
# Indexed question_4_anthropic_claude-3-haiku_online_20250522185908.md (file_id=file-WiKD1f9KBHHUSymKh2umhL)
# Uploading question_32_openai_gpt-4.1-mini_online_20250522192653.md (7356 bytes)…
# Indexed question_32_openai_gpt-4.1-mini_online_20250522192653.md (file_id=file-XHkdHPmJpgPzEgfSy4Vzdx)
# Uploading question_70_meta-llama_llama-4-scout_online_20250522200809.md (4978 bytes)…
# Indexed question_70_meta-llama_llama-4-scout_online_20250522200809.md (file_id=file-JBQ3WZdUoGJAPk1ucmzfck)
# Uploading question_31_openai_gpt-4.1-mini_online_20250522192558.md (5947 bytes)…
# Indexed question_31_openai_gpt-4.1-mini_online_20250522192558.md (file_id=file-QAa16XdCaz5o8rFhy845jN)
# Uploading question_71_anthropic_claude-3-haiku_online_20250522200901.md (4470 bytes)…
# Indexed question_71_anthropic_claude-3-haiku_online_20250522200901.md (file_id=file-GruU6CgcQ7cDb3HQCvyED5)
# Uploading question_15_openai_gpt-4.1-mini_online_20250522191038.md (7100 bytes)…
# Indexed question_15_openai_gpt-4.1-mini_online_20250522191038.md (file_id=file-B5AUcuVj5CZMQ1rGfS91WH)
# Uploading deep_research_Kuhikugu_Archaeological.md (3325 bytes)…
# Indexed deep_research_Kuhikugu_Archaeological.md (file_id=file-XvxV5ToRPAgRHndyBYDiq9)
# Uploading question_73_meta-llama_llama-4-scout_online_20250522201158.md (6559 bytes)…
# Indexed question_73_meta-llama_llama-4-scout_online_20250522201158.md (file_id=file-UpVK7QkyqmbctPUSz8rSuK)
# Uploading question_41_meta-llama_llama-4-scout_online_20250522193701.md (5911 bytes)…
# Indexed question_41_meta-llama_llama-4-scout_online_20250522193701.md (file_id=file-HoWpb99xhSqjASeJhSNS93)
# Uploading deep_research_competition_strategies_ideas.md (54724 bytes)…
# Indexed deep_research_competition_strategies_ideas.md (file_id=file-HSD3XikY61hCacC8KDgoUT)
# Uploading question_41_anthropic_claude-3-haiku_online_20250522193647.md (5324 bytes)…
# Indexed question_41_anthropic_claude-3-haiku_online_20250522193647.md (file_id=file-VTUSwsEPxofjgA7o79wPZn)
# Uploading question_16_meta-llama_llama-4-scout_online_20250522191209.md (4133 bytes)…
# Indexed question_16_meta-llama_llama-4-scout_online_20250522191209.md (file_id=file-6zb4huLtPLG6hwQWbbjN9e)
# Uploading question_10_anthropic_claude-3-haiku_online_20250522190620.md (3408 bytes)…
# Indexed question_10_anthropic_claude-3-haiku_online_20250522190620.md (file_id=file-9KUysgQZt2QSE4j28DfXn1)
# Uploading question_66_meta-llama_llama-4-scout_online_20250522200331.md (5250 bytes)…
# Indexed question_66_meta-llama_llama-4-scout_online_20250522200331.md (file_id=file-3L6s6TuqEqnGdcc9phXrW5)
# Uploading question_37_openai_gpt-4.1-mini_online_20250522193216.md (7278 bytes)…
# Indexed question_37_openai_gpt-4.1-mini_online_20250522193216.md (file_id=file-RbT29neLsHNNJDQqgQAgKc)
# Uploading question_68_anthropic_claude-3-haiku_online_20250522200513.md (5612 bytes)…
# Indexed question_68_anthropic_claude-3-haiku_online_20250522200513.md (file_id=file-Tu77kDMjXAaTRmTjFXaBMP)
# Uploading question_75_meta-llama_llama-4-scout_online_20250522201359.md (4489 bytes)…
# Indexed question_75_meta-llama_llama-4-scout_online_20250522201359.md (file_id=file-She4nzyt2VVpkDkncHLrSV)
# Uploading question_62_openai_gpt-4.1-mini_online_20250522195830.md (6826 bytes)…
# Indexed question_62_openai_gpt-4.1-mini_online_20250522195830.md (file_id=file-P9CegFPVceKGRtd3Q81StH)
# Uploading question_35_openai_gpt-4.1-mini_online_20250522193003.md (6825 bytes)…
# Indexed question_35_openai_gpt-4.1-mini_online_20250522193003.md (file_id=file-5KCPiVc5sQtxkvb9LLYmQn)
# Uploading deep_research_Open_Access_LiDAR_Datasets.md (3085 bytes)…
# Indexed deep_research_Open_Access_LiDAR_Datasets.md (file_id=file-8DdGyCNvK5qoE9kCSChaFm)
# Uploading question_16_openai_gpt-4.1-mini_online_20250522191145.md (5478 bytes)…
# Indexed question_16_openai_gpt-4.1-mini_online_20250522191145.md (file_id=file-TYMxPJVCfhimxFgtNdKFBF)
# Uploading question_52_anthropic_claude-3-haiku_online_20250522194820.md (5592 bytes)…
# Indexed question_52_anthropic_claude-3-haiku_online_20250522194820.md (file_id=file-PCm2mLGBiLBFopFW9EDt9N)
# Uploading question_68_openai_gpt-4.1-mini_online_20250522200458.md (7877 bytes)…
# Indexed question_68_openai_gpt-4.1-mini_online_20250522200458.md (file_id=file-FxYM4Jx4vvgKAGUfxLxoHh)
# Uploading question_49_anthropic_claude-3-haiku_online_20250522194537.md (4942 bytes)…
# Indexed question_49_anthropic_claude-3-haiku_online_20250522194537.md (file_id=file-1QeYfX36y8CgDg6zwMNmqh)
# Uploading question_63_anthropic_claude-3-haiku_online_20250522200000.md (5453 bytes)…
# Indexed question_63_anthropic_claude-3-haiku_online_20250522200000.md (file_id=file-GzSzWKiQKQ1Z4kPe2EdQtc)
# Uploading question_13_anthropic_claude-3-haiku_online_20250522190907.md (3397 bytes)…
# Indexed question_13_anthropic_claude-3-haiku_online_20250522190907.md (file_id=file-WJ7AFiV2qMgu88HiCTPnja)
# Uploading question_34_openai_gpt-4.1-mini_online_20250522192907.md (8046 bytes)…
# Indexed question_34_openai_gpt-4.1-mini_online_20250522192907.md (file_id=file-BPTUPADcy3Sd1giJjmvcM6)
# Uploading question_52_openai_gpt-4.1-mini_online_20250522194806.md (7971 bytes)…
# Indexed question_52_openai_gpt-4.1-mini_online_20250522194806.md (file_id=file-4cHcKBrAdX87eHVFdvpDhz)
# Uploading question_30_meta-llama_llama-4-scout_online_20250522192534.md (4330 bytes)…
# Indexed question_30_meta-llama_llama-4-scout_online_20250522192534.md (file_id=file-LXEXxjgvArfsvDL7WqdRe4)
# Uploading question_59_openai_gpt-4.1-mini_online_20250522195529.md (7396 bytes)…
# Indexed question_59_openai_gpt-4.1-mini_online_20250522195529.md (file_id=file-GK6JpjbX2aJNPTePRb9qry)
# Uploading question_26_anthropic_claude-3-haiku_online_20250522192156.md (3712 bytes)…
# Indexed question_26_anthropic_claude-3-haiku_online_20250522192156.md (file_id=file-33q3VhUEjjzkXJSNJb9CMv)
# Uploading question_40_meta-llama_llama-4-scout_online_20250522193605.md (4998 bytes)…
# Indexed question_40_meta-llama_llama-4-scout_online_20250522193605.md (file_id=file-VTLwc9sLgTFV8Uc43hxt8C)

# %% [markdown]
# # What are the locations of known archaeological sites in the Amazon Rainforest?

# %%
# 3. Answer Questions

question = """
What are the locations of known archaeological sites in the Amazon Rainforest?
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# Here is a list of **known archaeological sites in the Amazon Rainforest**, including their names, geographic coordinates, countries, and brief descriptions. This list covers sites from various cultures and time periods (pre-Columbian, colonial, etc.), both well-documented and recently discovered, across the Amazon Basin (Brazil, Peru, Ecuador, Bolivia, and more).
#
# ---
#
# ### 1. **Upano Valley Sites**
# - **Coordinates:** 2.1317°S, 78.1054°W
# - **Country:** Ecuador (Morona-Santiago)
# - **Description:** A cluster of at least 15 ancient settlements in the Upano River Valley, revealed by LiDAR. These “lost cities” date to c. 500 BC–AD 300/600 (Upano/Kilamope culture). Features include earthen platform mounds, dug roadways, and extensive agriculture—among the earliest known complex societies in Amazonia.
#   *[Source: en.wikipedia.org]*
#
# ---
#
# ### 2. **Jacó Sá Geoglyph Site**
# - **Coordinates:** 9°57′38″S, 67°29′51″W (Decimal: -9.9606, -67.4975)
# - **Country:** Brazil (Acre)
# - **Description:** One of over 450 pre-Columbian geometric earthworks in Acre, southwestern Amazon. Jacó Sá consists of large square ditches with a circular moat, built ~2,000 years ago. These geoglyphs indicate ancient land use and forest clearing for agriculture.
#   *[Source: agencia.fapesp.br]*
#
# ---
#
# ### 3. **Monte de Teso dos Bichos (Camutins)**
# - **Coordinates:** 0.983°S, 49.583°W
# - **Country:** Brazil (Marajó Island, Pará)
# - **Description:** A major mound complex built by the Marajoara culture (AD 400–1300). Teso dos Bichos is a 2.5 ha artificial mound, part of a network of ~30 mounds used for habitation above seasonal floods. Marajoara society is known for elaborate pottery and large-scale fish-farming/agriculture.
#   *[Source: en.wikipedia.org]*
#
# ---
#
# ### 4. **Caverna da Pedra Pintada**
# - **Coordinates:** 1.996°S, 54.071°W
# - **Country:** Brazil (Monte Alegre, Pará)
# - **Description:** Also called “Painted Rock Cave.” Contains rock art and evidence of human habitation ~11,200 years ago, making it one of the oldest sites in Amazonia. Excavated by Anna Roosevelt; features pictographs, Paleoindian tools, and plant remains.
#   *[Source: en.wikipedia.org]*
#
# ---
#
# ### 5. **Taperinha Shell Midden**
# - **Coordinates:** 2.443°S, 54.280°W
# - **Country:** Brazil (Santarém, Pará)
# - **Description:** An ancient shell mound on a terra firme bluff near the Amazon River. Famous for yielding some of the earliest ceramics in the Americas.
#   *[Source: en.wikipedia.org]*
#
# ---
#
# ### 6. **Paratoari (Pyramids of Paratoari)**
# - **Coordinates:** -12.6706, -71.4567
# - **Country:** Peru (Manu region)
# - **Description:** Natural pyramid-shaped formations in the southeastern Peruvian Amazon. Attracted archaeological interest due to their unusual shape and possible cultural significance.
#   *[Source: latitude.to]*
#
# ---
#
# ### 7. **Fonte Boa Site (approximate)**
# - **Coordinates:** ~ -7.1, ~ -66.88
# - **Country:** Brazil (near Acre)
# - **Description:** Mounded ring village and geometric enclosures typical of

# %% [markdown]
# # What is the location of Kuhikugu (GPS coordinate)?

# %%
question = """
What is the location of Kuhikugu (GPS coordinate)?
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# The central GPS coordinates of the Kuhikugu archaeological complex are approximately **12°33′30″S, 53°6′40″W** (decimal: **-12.5583, -53.1111**).
#
# **References:**
# - Wikipedia: Kuhikugu – Archaeological site in Brazil’s Upper Xingu (coordinates, discovery and description) ([en.wikipedia.org](https://en.wikipedia.org/wiki/Kuhikugu))
# - Source: deep_research_Kuhikugu_Archaeological.md
# - Source: deep_research_Known_Archaeological_Sites_2.md

# %% [markdown]
# # What are the locations of suspected archaeological sites in the Brazilian Amazon Rainforest from the literature that have not yet been confirmed?

# %%
question = """
What are the locations of suspected archaeological sites
in the Brazilian Amazon Rainforest from the
literature that have not yet been confirmed?"
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# **Locations of Suspected but Unconfirmed Archaeological Sites in the Brazilian Amazon Rainforest (from the literature):**
#
# ---
#
# ### 1. **Belterra Plateau & Tapajós National Forest (Flona-Tapajós), near Santarém (Pará)**
# - **Description:** LiDAR surveys have revealed non-randomly distributed depressions ("Poços de Água") and possible settlement patterns extending deep into the forest, suggesting previously unknown Pre-Columbian habitation.
# - **Status:** Identified via remote sensing; not yet confirmed by fieldwork.
# - **Reference:** Stenborg et al. 2018 ([tandfonline.com](https://www.tandfonline.com/doi/full/10.1080/00934690.2017.1417198))
#
# ---
#
# ### 2. **Southern Amazonia – Headwaters of the Tapajós River (Pará/Mato Grosso)**
# - **Description:** Extensive clusters of ditched enclosures and mound villages (fortified settlements) have been detected by LiDAR and predictive modeling across an 1,800 km stretch, especially in the Upper Tapajós Basin.
# - **Status:** Most sites remain unexcavated and unconfirmed; only a subset has been ground-truthed.
# - **References:**
#   - Gregorio de Souza et al. 2018 ([pubmed.ncbi.nlm.nih.gov](https://pubmed.ncbi.nlm.nih.gov/29588444/))
#   - Peripato et al. 2023 ([Science](https://www.science.org/doi/10.1126/science.adg7700))
#
# ---
#
# ### 3. **Upper Xingu Basin (Mato Grosso)**
# - **Description:** LiDAR has revealed a large, ring-ditch fortified village (plaza-town) beneath the forest canopy, similar to known pre-Columbian settlements, but this site remains unexcavated.
# - **Status:** Detected remotely; awaiting field verification.
# - **Reference:** [rainfor.org](https://www.rainfor.org/)
#
# ---
#
# ### 4. **Upper Purús River Region (Acre/Western Amazonia)**
# - **Description:** Numerous geometric earthworks and geoglyphs (rectangular/circular ditches) have been identified, with many more suspected based on landscape patterns and remote sensing.
# - **Status:** Several sites documented remotely; many remain unconfirmed by excavation.
# - **References:**
#   - Pärssinen et al. 2009 ([cambridge.org](https://www.cambridge.org/core/journals/antiquity/article/abs/precolumbian-geometric-earthworks-in-the-upper-purus-a-complex-society-in-western-amazonia/CF5DB06F57758F24C32449BD4B2C5AFB))
#   - Peripato et al. 2023
#
# ---
#
# ### 5. **Acre State (Southwestern Amazon) – Purus-Madeira Interfluve**
# - **Description:** At least 13 new geoglyph sites (large geometric earthen enclosures) have been predicted by satellite and modeling studies, expanding the known distribution of Acre’s geoglyph complexes.
# - **Status:** Identified by remote sensing/modeling; not yet confirmed by excavation.
# - **Reference:** Peripato et al. 2023; [researchgate.net](https://www.researchgate.net/publication/374567890)
#
# ---
#
# ### 6. **Central Amazon Floodplain (Amazon River Basin)**
# - **Description:** Two large geometric earthwork features detected on the floodplain, possibly anthropogenic (e.g., ancient fish weirs or water management structures).
# - **Status:** Detected by remote sensing; function and origin unconfirmed.
# - **Reference:** [rainfor.org](https://www.rainfor.org/)
#
# ---
#
# ### 7

# %% [markdown]
# # What locations in the Amazon Rainforest match descriptions from historical accounts but haven't been verified on the ground?

# %%
question = """
What locations in the Amazon Rainforest match descriptions from historical accounts but haven't been verified on the ground?
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# Several locations in the Brazilian Amazon Rainforest match descriptions from historical accounts—such as early explorer reports or indigenous oral histories—but have not yet been verified archaeologically on the ground. Recent advances in remote sensing (LiDAR, satellite imagery) and predictive modeling have highlighted these areas as high-probability candidates for ancient settlements, earthworks, or engineered landscapes. Below are the main regions identified in the literature:
#
# ---
#
# ### 1. **Upper Xingu, Mato Grosso (Southern Amazonia)**
# - **Description:** Historical accounts and indigenous oral traditions describe large, organized settlements with plazas and defensive ditches, similar to those reported by early explorers (e.g., Karl von den Steinen, 19th century).
# - **Modern Evidence:** LiDAR has revealed a fortified village site (ancient plaza-town) with a central plaza and ditched enclosure beneath the forest canopy, matching these descriptions.
# - **Status:** The site remains unexcavated and unverified on the ground.
# - **Source:** *deep_research_Suspected_Unconfirmed_Sites.md*; [rainfor.org](https://www.rainfor.org/)
#
# ---
#
# ### 2. **Southwestern Amazon (Acre/Purus-Madeira Region)**
# - **Description:** Early travelers and rubber tappers reported geometric earthworks and mounds in the forest, which were later echoed in indigenous narratives.
# - **Modern Evidence:** LiDAR and satellite imagery have revealed multiple geoglyph earthworks (rectangular and circular ditched enclosures) on interfluvial plateaus, consistent with these historical accounts.
# - **Status:** These features have not been confirmed by ground-truthing or excavation.
# - **Source:** *deep_research_Suspected_Unconfirmed_Sites.md*; [rainfor.org](https://www.rainfor.org/)
#
# ---
#
# ### 3. **Upper Tapajós Basin (Pará/Mato Grosso)**
# - **Description:** Colonial-era reports and indigenous oral histories reference large, fortified villages and mound complexes in the Tapajós headwaters.
# - **Modern Evidence:** Remote surveys have identified an extensive cluster of 81 prehistoric sites (ditched enclosures and mound villages) forming a network over ~1,800 km, matching the scale and layout described historically.
# - **Status:** Most sites remain unexcavated and unverified on the ground.
# - **Source:** *deep_research_Suspected_Unconfirmed_Sites.md*; [nature.com](https://www.nature.com/articles/s41597-021-01067-7.pdf)
#
# ---
#
# ### 4. **Central Amazon Floodplain (Amazon River Basin)**
# - **Description:** Historical accounts mention large engineered features (possibly fish weirs or water management structures) along the floodplains.
# - **Modern Evidence:** Remote sensing has detected two large geometric earthwork features with straight edges, consistent with these descriptions.
# - **Status:** Awaiting on-site verification; their function is hypothesized from context.
# - **Source:** *deep_research_Suspected_Unconfirmed_Sites.md*; [rainfor.org](https://www.rainfor.org/)
#
# ---
#
# ### 5. **Acre State, Western Amazon**
# - **Description:** Early 20th-century rubber tappers and explorers described mysterious geometric clearings and mounds.
# - **Modern Evidence:** At least 13 new geoglyph sites have been identified via predictive modeling and satellite analysis, matching these historical reports.
# - **Status:** Remain unconfirmed by excavation.
# - **Source:** *deep_research_Suspected_Unconfirmed_Sites.md*; [researchgate.net](https://www.researchgate.net/)
#
# ---
#
# ### 6. **Eastern Amazon (Along Major Rivers)**
# - **Description:** Historical sources and indigenous knowledge refer to fertile “dark earth” (terra preta) patches associated with ancient settlements.
# - **Modern Evidence:** Modeling studies predict numerous high-probability terra preta sites along the Amazon

# %% [markdown]
# # What techniques have been used to discover new archaeological sites in the Amazon rainforest in recent years?

# %%
question = """
What techniques have been used to discover new archaeological sites in the Amazon rainforest in recent years?
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# **Recent Techniques for Discovering New Archaeological Sites in the Amazon Rainforest (2019–2024):**
#
# Recent years have seen a dramatic expansion in the discovery of hidden archaeological sites in the Amazon, driven by a combination of advanced remote sensing technologies and machine learning (ML) models. The main techniques include:
#
# ---
#
# ### 1. **Airborne LiDAR (Light Detection and Ranging)**
# - **How it works:** LiDAR emits laser pulses from aircraft or drones to map the ground surface in 3D, penetrating dense forest canopies.
# - **Impact:** LiDAR has “digitally deforested” the Amazon, revealing earthworks, mounds, ditches, roads, canals, and even entire lost towns invisible to the naked eye or conventional aerial photography.
# - **Recent discoveries:**
#   - In Acre and Mato Grosso (Brazil), LiDAR revealed dozens of previously unknown circular and rectangular villages, geometric geoglyphs, and complex engineered landscapes ([Smithsonianmag.com](https://www.smithsonianmag.com/), [news.mongabay.com](https://news.mongabay.com/)).
#   - In 2023, a large-scale LiDAR study covering just 0.1% of the Amazon identified 24 new sites, suggesting over 10,000 earthworks remain undiscovered ([Peripato et al., 2023, Science](https://www.science.org/doi/10.1126/science.adh3771)).
#   - In 2024, drone-mounted LiDAR rediscovered a lost 18th-century Portuguese colonial town in Rondônia, also exposing much older indigenous features ([Washington Post](https://www.washingtonpost.com/)).
# - **Advantages:** High-resolution, can see through vegetation, reveals subtle anthropogenic features.
# - **Limitations:** Expensive, limited coverage so far, requires expert interpretation (though ML is automating this).
#
# ---
#
# ### 2. **Machine Learning Models Applied to Remote Sensing Data**
# - **Deep Learning on LiDAR Data:**
#   - **Convolutional Neural Networks (CNNs):** Trained to automatically detect archaeological features (e.g., mounds, ditches, geometric enclosures) in LiDAR-derived elevation models.
#   - **Effectiveness:** High accuracy (often 80–90%+ in tests), greatly speeds up site detection compared to manual analysis ([Fiorucci et al., 2022](https://www.livescience.com/)).
#   - **Use cases:** Automated detection of “clock face” villages, earthworks, and causeways in Acre and other regions.
# - **Predictive Spatial Modeling:**
#   - **Random Forests and Other Classifiers:** Used to predict the probability of archaeological site occurrence based on environmental variables (soil, hydrology, topography, vegetation).
#   - **Example:** Walker et al. (2023) used a random forest model with 65 variables to predict earthwork and ADE (Amazonian Dark Earth) sites, achieving AUC ~0.91 and successfully guiding field surveys to new discoveries ([Walker et al., 2023, PeerJ](https://peerj.com/articles/15137/)).
#   - **Industry Application:** TechnoLynx’s AI system identified multiple ancient settlement sites, later confirmed by ground truthing ([technolynx.com](https://technolynx.com/)).
# - **Spectral Classification:**
#   - ML models analyze multispectral/hyperspectral satellite data to detect vegetation or soil anomalies indicative of buried features.
#
# ---
#
# ### 3. **Satellite Multispectral and Hyperspectral Imagery**
# - **How it works:** Satellite sensors capture data in multiple wavelengths, revealing subtle differences in vegetation health or soil chemistry that may signal buried archaeological remains.
# - **Applications:** Used to identify anthropogenic soils (ADEs), geometric earthworks, and settlement patterns, especially in deforested or partially cleared areas ([

# %% [markdown]
# # Were historical and indigenous texts analyzed using machine learning or a large language model to identify potential archaeological site locations?

# %%
question = """
Were historical and indigenous texts analyzed using machine
learning or a large language model to identify potential archaeological site locations?
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# Based on the provided context, **historical and indigenous texts have not yet been systematically analyzed using machine learning (ML) or large language models (LLMs) to directly identify potential archaeological site locations in the Amazon**. The main ML applications described in the sources focus on remote sensing data (LiDAR, satellite imagery, environmental predictors) and not on textual analysis of historical or indigenous documents.
#
# However, the context does discuss the **potential and strategies for using LLMs** (such as GPT-4) to analyze historical texts, colonial diaries, and indigenous accounts for archaeological prospecting:
#
# - **LLMs can be used to extract geographic clues from old exploration narratives**, such as mentions of rivers, directions, and distances, which could then be geocoded to approximate site locations. For example, prompts like “Read this expedition diary text and extract every sentence that mentions a river, compass direction, or distance traveled” are suggested as ways to mine texts for relevant information (deep_research_competition_strategies_ideas.md).
# - **LLMs can translate and summarize non-English documents** (e.g., Portuguese or Spanish reports), making them accessible for archaeological research.
# - **LLMs can help identify patterns in site descriptions** by summarizing and comparing environmental and locational features across known sites.
#
# These are described as **recommended or emerging strategies**, not as methods that have already been systematically implemented in published Amazonian archaeological research. The context emphasizes that LLMs are valuable tools for augmenting human research in literature review, data extraction, and hypothesis generation, but it does not cite any studies where ML or LLMs have directly led to the discovery of archaeological sites through automated analysis of historical or indigenous texts.
#
# **In summary:**
# - **No published Amazonian archaeological discoveries have yet resulted from ML or LLM analysis of historical or indigenous texts.**
# - **LLMs are recognized as promising tools for this purpose, and workflows are being developed, but their use is currently at the stage of recommendation and experimentation, not established practice.**
#
# **References:**
# - deep_research_competition_strategies_ideas.md (sections 3.1 and 3.2)
# - No mention of such text-based ML/LLM discovery in the main archaeological ML literature cited (Walker et al. 2023; Peripato et al. 2023; Iriarte et al. 2020, etc.).

# %% [markdown]
# # What is the impact of the presence of Amazonian dark earth on vegetation? How could this be used to detect potential unexplored archaeological sites using satellite imagery and machine learning?

# %%
question = """
What is the impact of the presence of Amazonian dark earth on vegetation?
How could this be used to detect potential
unexplored archaeological sites using satellite imagery and machine learning? 
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# ### Impact of Amazonian Dark Earth (ADE) on Vegetation
#
# **Amazonian Dark Earths (ADEs)**, or *terra preta*, are anthropogenic soils created by ancient human activity. Their presence has a marked impact on the vegetation growing above them:
#
# - **Altered Vegetation Structure and Composition:** Forests over ADEs often differ from those on typical Amazonian soils. They tend to have more palms, shorter trees, and a higher proportion of secondary growth species. This is likely because ADEs mark the sites of former settlements, gardens, or agricultural fields, where centuries of human activity and later regrowth have shaped the plant community ([eos.org](https://eos.org)).
# - **Vegetation Density and Moisture:** Satellite studies have shown that canopy vegetation over ADEs is often **less dense** and has **lower moisture content** than surrounding primary forest. This is somewhat counterintuitive, as one might expect richer soils to support lusher growth. However, the explanation lies in the legacy of disturbance: ADE forests are typically regrowth on old habitation sites, so the canopy is lower and less continuous ([eos.org](https://eos.org)).
# - **Vegetation Indices:** These differences are reflected in satellite-derived indices. For example, **Normalized Difference Vegetation Index (NDVI)** values are often **lower** over ADEs, and canopy water content is reduced compared to adjacent undisturbed forests. These contrasts become especially pronounced during drought years, when ADE forests brown out more than others ([eos.org](https://eos.org)).
#
# ### Using These Effects to Detect Unexplored Archaeological Sites
#
# The unique impact of ADEs on vegetation provides a **remote sensing signature** that can be exploited to locate potential archaeological sites:
#
# 1. **Spectral and Vegetation Anomalies:**
#    - **Multispectral and Hyperspectral Satellite Imagery:** Satellites like Landsat, Sentinel-2, and hyperspectral sensors can detect subtle differences in canopy reflectance, NDVI, and moisture indices over ADEs. These anomalies can be mapped even under dense forest cover ([eos.org](https://eos.org); [wired.com](https://www.wired.com/2012/12/satellite-sensing-black-earth-amazon/?cid=4800984)).
#    - **Soil Exposure in Cleared Areas:** In agricultural or deforested zones, ADEs may be visible directly as unusually dark, nutrient-rich soil patches, which stand out from the typical red or yellow Amazonian soils ([daneshyari.com](https://daneshyari.com)).
#
# 2. **Machine Learning and Predictive Modeling:**
#    - **Training on Known Sites:** Machine learning (ML) models (e.g., random forests, convolutional neural networks) can be trained on the spectral and environmental characteristics of known ADE sites—including vegetation indices, soil reflectance, proximity to water, and topography ([Walker et al. 2023](https://pubmed.ncbi.nlm.nih.gov/37020851)).
#    - **Automated Detection:** Once trained, these models can scan vast satellite datasets to flag areas with similar spectral “fingerprints,” identifying high-probability targets for unexplored archaeological sites. For example, ML models have achieved high accuracy (AUC ~0.91) in predicting ADE and earthwork locations ([Walker et al. 2023](https://pubmed.ncbi.nlm.nih.gov/37020851)).
#    - **Integration with LiDAR:** In areas where LiDAR is available, ML can combine canopy and elevation data to further refine site predictions, revealing earthworks and settlement layouts often associated with ADEs ([deep_research_Machine_Learning_Models_2.md](#)).
#
# 3. **Ground Verification and Discovery:**
#    - **Guiding Fieldwork:** These remote predictions can direct archaeologists to previously unknown sites for ground-truthing, dramatically increasing the efficiency

# %% [markdown]
# # What open-access LIDAR datasets cover portions of the Brazilian Amazon?

# %%
question = """
What open-access LIDAR datasets cover portions of the Brazilian Amazon?
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# Several **open-access LIDAR datasets** cover portions of the Brazilian Amazon, providing valuable resources for research on forest structure, biomass, disturbance, and even archaeological features. The most significant datasets are:
#
# ---
#
# ### 1. **EBA Project Airborne LIDAR Transects (2016–2018)**
# - **Description:** Over 900 airborne LIDAR transects (each 12.5 km × 0.3 km, ~375 ha) sampled across the Brazilian Amazon as part of the Estimating Biomass in Amazonia (EBA) project.
# - **Data:** LAS point clouds (~4 pts/m²), suitable for canopy structure, gap dynamics, biomass, and detection of earthworks.
# - **Access:** [Zenodo repository](https://zenodo.org/record/4288474) and [Nature article](https://www.nature.com/articles/s41598-020-80809-w)
# - **Reference:** Aragão et al., 2021, *Scientific Reports*.
#
# ---
#
# ### 2. **NASA/Embrapa Sustainable Landscapes LIDAR (2008–2018)**
# - **Description:** High-resolution airborne LIDAR surveys over select sites in Acre, Amazonas, Pará, Rondônia, and other states, collected for forest biomass and carbon monitoring.
# - **Data:** Point clouds (~10 pts/m²), 1 km² tiles, with Digital Terrain Models (DTMs) at ~1 m resolution.
# - **Access:** [ORNL DAAC](https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=2007) (free EarthData login required).
#
# ---
#
# ### 3. **Manaus Region Forest LIDAR (2008)**
# - **Description:** Airborne LIDAR over forest research sites near Manaus (Cuieiras Biological Reserve, Adolpho Ducke Reserve, BDFFP).
# - **Data:** Raw point clouds and DTMs (~1 m resolution).
# - **Access:** [ORNL DAAC](https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=2007).
#
# ---
#
# ### 4. **Tapajós National Forest LIDAR (2008)**
# - **Description:** Airborne LIDAR surveys in Tapajós (Pará state), covering flux tower areas and selectively logged sites.
# - **Data:** Point clouds and 1 m DTM grids.
# - **Access:** [ORNL DAAC](https://daac.ornl.gov/cgi-bin/dsviewer.pl?ds_id=1284).
#
# ---
#
# ### 5. **Monitoring Selective Logging in Western Amazonia (Acre, 2010–2011)**
# - **Description:** Repeat LIDAR flights to monitor selective logging impacts on canopy structure and biomass in Acre.
# - **Data:** Canopy height models, biomass change, logging disturbance.
# - **Access:** [ScienceDirect article](https://www.sciencedirect.com/science/article/pii/S0034425713003441).
#
# ---
#
# ### 6. **Antimary State Forest LIDAR (Acre State)**
# - **Description:** Airborne LIDAR and ground plots for biomass estimation and low-intensity logging detection.
# - **Data:** LIDAR metrics, canopy height, biomass models.
# - **Access:** [ScienceDirect article](https://www.sciencedirect.com/science/article/pii/S0034425712002179).
#
# ---
#
# ### 7. **NASA GEDI Satellite LIDAR (2019–present)**
# - **Description:** Spaceborne LIDAR providing billions of footprints (~25 m diameter, ~60 m spacing) across the Amazon.
# - **Data:** Canopy height and ground elevation; not continuous but dense sampling.
# - **Access:** [NASA Earthdata GEDI Portal](https://lpdaac.usgs.gov/products/gedi02_av002/).
#
# ---

# %% [markdown]
# # What machine learning models have successfully identified archaeological features beneath forest canopy?

# %%
question = """
What machine learning models have successfully identified archaeological features beneath forest canopy?
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# Several machine learning (ML) models have **successfully identified archaeological features beneath forest canopy**, especially when paired with remote sensing data such as LiDAR, multispectral, and hyperspectral imagery. The most prominent and effective models and approaches include:
#
# ---
#
# ## 1. **Random Forest Classifiers**
# - **Description:** Ensemble tree-based models that classify regions as likely or unlikely to contain archaeological features based on environmental and remote sensing variables.
# - **Successes:**
#   - **Walker et al. (2023)** used a random forest model trained on 65 environmental variables (including LiDAR, climate, and soil data) to predict the presence of earthworks and Amazonian Dark Earth (ADE) sites in the Brazilian Amazon. The model achieved high accuracy (AUC ≈ 0.91) and led to the discovery of 13 new geoglyph sites in areas flagged as high-probability by the model ([Walker et al., 2023, PeerJ](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10496461/)).
#   - Random forests have outperformed neural networks, support vector machines, and gradient-boosted trees in some Amazonian site prediction tasks ([deep_research_Machine_Learning_Models.md](#)).
#
# ---
#
# ## 2. **Convolutional Neural Networks (CNNs)**
# - **Description:** Deep learning models adept at recognizing spatial patterns in imagery, including subtle geometric or textural anomalies indicative of archaeological features.
# - **Successes:**
#   - CNNs have been used to analyze LiDAR-derived digital elevation models (DEMs) and high-resolution aerial/satellite images to automatically detect features such as circular mounds, linear embankments, and geometric earthworks hidden beneath forest canopy ([deep_research_Machine_Learning_Models.md](#); [Fiorucci et al., 2022](https://www.livescience.com/archaeology/)).
#   - In Amazonia, CNNs have been trained to flag anthropogenic relief anomalies in large LiDAR datasets, accelerating the identification of hidden sites ([deep_research_Machine_Learning_Models_2.md](#)).
#
# ---
#
# ## 3. **U-Net (Deep Learning Segmentation Networks)**
# - **Description:** A specialized CNN architecture for image segmentation, capable of delineating individual objects or features within complex remote sensing data.
# - **Successes:**
#   - **Wagner et al. (2020)** used U-Net to segment and map individual palm crowns in Amazonian forests from very-high-resolution multispectral imagery, achieving ~95% mapping accuracy (F1 ≈ 0.7). Certain palm species serve as proxies for past human activity ([Wagner et al., 2020, MDPI](https://www.mdpi.com/)).
#   - U-Net has also been applied to airborne LiDAR data to detect over a million palm tree segments, which can indicate anthropogenic landscapes ([Dal’Agnol da Silva et al., 2022](https://www.researchgate.net/)).
#
# ---
#
# ## 4. **Mask R-CNN (Region-based Convolutional Neural Networks)**
# - **Description:** An advanced deep learning model for object detection and segmentation, particularly effective on LiDAR-derived DEMs.
# - **Successes:**
#   - Modified Mask R-CNN models have been used to automate the detection of archaeological sites in high-resolution LiDAR data, successfully identifying features in forested regions of Europe ([Wiley, 2022](https://onlinelibrary.wiley.com/doi/10.1002/arp.1806)).
#
# ---
#
# ## 5. **Hybrid Approaches (LiDAR + Multispectral/Hyperspectral + ML)**
# - **Description:** Combining LiDAR with multispectral or hyperspectral satellite imagery, then applying ML classifiers (e.g., random forest, SVM, CNN) to detect features based on both elevation

# %% [markdown]
# #  How are radar (e.g., Sentinel-1 SAR) and hyperspectral data being combined with LIDAR for sub-canopy detection?

# %%
question = """
How are radar (e.g., Sentinel-1 SAR) and hyperspectral data being combined with LIDAR for sub-canopy detection?
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# Radar (e.g., Sentinel-1 SAR), hyperspectral, and LIDAR data are being **combined through multi-level data fusion approaches** to significantly improve sub-canopy detection in forested and complex vegetated environments. Here’s how each data type contributes and how their integration is achieved:
#
# ---
#
# ### **1. Complementary Strengths**
#
# - **LIDAR** provides high-resolution 3D structural information, mapping vertical vegetation layers and ground elevation—even through canopy gaps.
# - **Hyperspectral data** offers detailed spectral signatures, enabling discrimination of vegetation types, health, and biochemical properties, but struggles with spectral mixing in dense or heterogeneous canopies.
# - **Radar (SAR)**, such as Sentinel-1, uses longer wavelengths that partially penetrate the canopy, providing information on sub-canopy structure, surface roughness, and moisture content.
#
# ---
#
# ### **2. Fusion Approaches**
#
# **Data fusion** can occur at several levels ([Li, 2021](https://www.sciencedirect.com/science/article/pii/S1367578821000110); [Tusa et al., 2019](https://www.sciencedirect.com/science/article/pii/B9780444639776000134)):
#
# - **Low-level (Observation-level) Fusion:**
#   Directly combines raw data (e.g., stacking LIDAR point clouds, hyperspectral bands, and radar backscatter) to create a unified dataset for analysis.
#
# - **Medium-level (Feature-level) Fusion:**
#   Extracts features from each source (e.g., LIDAR-derived canopy height, hyperspectral vegetation indices, radar texture/backscatter statistics) and merges them for classification or regression tasks.
#
# - **High-level (Decision-level) Fusion:**
#   Independently analyzes each data type, then combines their classification or detection outputs using ensemble or voting methods.
#
# ---
#
# ### **3. Addressing Sub-Canopy Complexity**
#
# - **Spectral Mixing:**
#   Hyperspectral data alone can be confounded by mixed signals from soil, litter, and multiple vegetation layers. LIDAR’s structural data and radar’s partial penetration help disentangle these signals, allowing for more accurate sub-canopy class identification ([Mitchell, 2019](https://www.mdpi.com/2072-4292/11/18/2141/htm)).
#
# - **Vertical Layer Separation:**
#   LIDAR’s vertical profiles, when combined with radar’s sensitivity to structure and hyperspectral’s species-level detail, enable the detection and mapping of understory vegetation and ground features that would otherwise be obscured by the upper canopy.
#
# ---
#
# ### **4. Practical Applications**
#
# - **Tree Species Classification:**
#   UAV-based hyperspectral and LIDAR fusion improves the distinction of canopy and sub-canopy species, especially in complex tropical forests ([David et al., 2023](https://www.mdpi.com/1999-4907/14/5/945)).
#
# - **Forest Monitoring:**
#   Integrated LIDAR, hyperspectral, and radar data support large-scale monitoring of forest structure, composition, and sub-canopy vegetation dynamics ([Sankey et al., 2017](https://www.sciencedirect.com/science/article/pii/S0034425717301578)).
#
# ---
#
# ### **Summary Table**
#
# | Data Type      | Key Contribution                  | Limitation Alone           | Benefit in Fusion                  |
# |----------------|-----------------------------------|----------------------------|------------------------------------|
# | LIDAR          | 3D structure, vertical profiles   | Limited spectral info      | Separates canopy/sub-canopy layers |
# | Hyperspectral  | Species/biochemical discrimination| Spectral mixing, no structure | Enhanced species mapping           |
# | Radar (SAR)    | Structure, moisture, penetration  | Lower spatial resolution   | Reveals sub-canopy structure       |
#
# ---
#
# ### **References**
#
# 1. Li, S. (2021). [A comprehensive review of

# %% [markdown]
# #  What benchmark datasets and evaluation metrics are commonly used to compare canopy-penetrating algorithms?

# %%
question = """
What benchmark datasets and evaluation metrics are commonly used to compare canopy-penetrating algorithms?
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# **Benchmark datasets and evaluation metrics are essential for objectively comparing canopy-penetrating algorithms, such as those used for individual tree crown detection and delineation from remote sensing data.**
#
# ---
#
# ## Common Benchmark Datasets
#
# 1. **NeonTreeEvaluation**
#    - *Description*: Provides airborne RGB, hyperspectral, and LiDAR imagery with manual tree annotations.
#    - *Purpose*: Benchmark for tree detection algorithms using multimodal data.
#    - *Reference*: [GitHub - NeonTreeEvaluation](https://github.com/weecology/NeonTreeEvaluation)
#
# 2. **National Ecological Observation Network (NEON) Dataset**
#    - *Description*: Large-scale, co-registered airborne RGB, LiDAR, and hyperspectral imagery with annotated tree crowns.
#    - *Purpose*: Benchmark for canopy crown detection and delineation; supports reproducible and transparent algorithm evaluation.
#    - *Reference*: [Weinstein et al., 2021, PLOS Comp Biol](https://journals.plos.org/ploscompbiol/article/file?id=10.1371/journal.pcbi.1009180&type=printable)
#
# 3. **Open-Canopy**
#    - *Description*: Country-scale (France) benchmark for canopy height estimation at 1.5 m resolution, using SPOT satellite imagery and high-resolution aerial LiDAR.
#    - *Variants*: Includes Open-Canopy-Δ for canopy height change detection between years.
#    - *Reference*: [Fogel et al., 2024, arXiv](https://arxiv.org/abs/2407.09392)
#
# 4. **ISPRS International Contest of Individual Tree Crown (ITC) Segmentation**
#    - *Description*: Benchmark for individual tree crown segmentation using various data types and sensors.
#    - *Reference*: [ISPRS ITC Segmentation Contest](https://www2.isprs.org/commissions/comm3/wg1/itc-segmentation-contest/)
#
# 5. **Heterogeneous Forest Data from the Alpine Space**
#    - *Description*: LiDAR-based dataset covering diverse forest types (coniferous, deciduous, mixed) in the Alps, with varying stand structures and densities.
#    - *Purpose*: Evaluates single tree detection methods across heterogeneous conditions.
#    - *Reference*: [Eysn et al., 2015, MDPI Forests](https://www.mdpi.com/1999-4907/6/5/1721)
#
# ---
#
# ## Common Evaluation Metrics
#
# 1. **Detection Accuracy**
#    - Measures the proportion of correctly identified tree crowns.
#
# 2. **Precision**
#    - The proportion of true positives among all positive predictions (how many detected crowns are correct).
#
# 3. **Recall**
#    - The proportion of true positives among all actual positives (how many actual crowns were detected).
#
# 4. **F1-score**
#    - The harmonic mean of precision and recall, balancing both metrics.
#
# 5. **Intersection over Union (IoU)**
#    - The ratio of the intersection area to the union area between predicted and actual tree crowns; used for evaluating spatial overlap in delineation.
#
# 6. **Root Mean Square Error (RMSE)**
#    - Used for canopy height estimation, measuring the average error between predicted and actual tree heights.
#
# 7. **Change Detection Accuracy**
#    - For datasets like Open-Canopy-Δ, evaluates the ability to detect changes in canopy height over time.
#
# ---
#
# **Summary:**
# The most commonly used benchmark datasets for canopy-penetrating algorithms include NeonTreeEvaluation, the NEON dataset, Open-Canopy, the ISPRS ITC Segmentation Contest, and the Alpine Space dataset. Standard evaluation metrics are precision, recall, F1-score, IoU, RMSE (for height), and change detection accuracy. These resources and metrics enable robust, reproducible, and comparable assessments of algorithm performance across different forest types and remote sensing modalities.
#
# **References:**
# -

# %% [markdown]
# # What common geographical features are shared among verified archaeological sites in the Amazon?

# %%
question = """
What common geographical features are shared among verified archaeological sites in the Amazon?
"""

display(Markdown(answer_question(vs_id, question)))
# Out:
# Verified archaeological sites in the Amazon consistently share several key geographical features, reflecting both environmental opportunities and ancient human adaptation strategies. The most commonly identified features are:
#
# ---
#
# ### 1. **Proximity to Water Sources**
# Most sites are located near rivers, streams, lakes, or wetlands. Access to water was crucial for transportation, fishing, agriculture, and daily sustenance. This pattern is especially evident along the southern rim of the Amazon and in the Peruvian Amazon, where clusters of sites follow major waterways ([Iriarte et al., 2018](https://www.nature.com/articles/s41467-018-03510-7); [Walker, 2023](https://peerj.com/articles/15137/)).
#
# ---
#
# ### 2. **Elevated or Well-Drained Terrain (Terra Firme)**
# Sites are frequently found on slightly elevated ground or terra firme—areas above the seasonal floodplain. This placement protects settlements and earthworks from flooding while still allowing access to fertile alluvial soils ([Science, 2023](https://www.science.org/content/article/laser-mapping-reveals-hidden-structures-in-amazon-hints-thousands-more); [Elsevier, 2023](https://linkinghub.elsevier.com/retrieve/pii/S0277379116300919)).
#
# ---
#
# ### 3. **Fertile and Anthropogenic Soils (Terra Preta/ADE)**
# Many sites are associated with patches of highly fertile, human-created soils known as Terra Preta or Amazonian Dark Earths (ADE). These soils result from long-term deposition of organic matter and char, enabling intensive agriculture and supporting larger populations ([Walker, 2023](https://peerj.com/articles/15137/)).
#
# ---
#
# ### 4. **Forested Environments and Landscape Modification**
# Sites are typically embedded within forested landscapes, but often show evidence of deliberate landscape modification—such as raised fields, causeways, ditches, and mounds. These modifications improved drainage, facilitated agriculture, and connected settlements, indicating sophisticated environmental management ([Science, 2023](https://www.science.org/content/article/laser-mapping-reveals-hidden-structures-in-amazon-hints-thousands-more); [Elsevier, 2023](https://linkinghub.elsevier.com/retrieve/pii/S0277379116300919)).
#
# ---
#
# ### 5. **Strategic Placement for Social and Trade Networks**
# Many sites are found along ecological boundaries (ecotones) or in linear arrangements along floodplain corridors. This facilitated inter-community exchange and integration, especially among culturally related groups such as the Arawak-speaking populations ([Iriarte et al., 2018](https://www.nature.com/articles/s41467-018-03510-7)).
#
# ---
#
# **Summary Table of Common Features:**
#
# | Feature                              | Description/Function                                         | Key References                                                                                   |
# |---------------------------------------|-------------------------------------------------------------|--------------------------------------------------------------------------------------------------|
# | Proximity to water                   | Resource access, transport, fertile soils                   | [Nature, 2018](https://www.nature.com/articles/s41467-018-03510-7); [PeerJ, 2023](https://peerj.com/articles/15137/) |
# | Elevated/well-drained terrain        | Flood avoidance, agriculture                                | [Science, 2023](https://www.science.org/content/article/laser-mapping-reveals-hidden-structures-in-amazon-hints-thousands-more) |
# | Fertile/anthropogenic soils (ADE)    | Intensive agriculture, population support                   | [PeerJ, 2023](https://peerj.com/articles/15137/)                                                 |
# | Forested environment & modification  | Timber, game, landscape engineering                         | [Elsevier, 2023](https://linkinghub.elsevier.com/retrieve/pii/S0277379116300919)

# %%
# Clean up
# Option 1: Clean up specific vector store
cleanup_vector_store(vs_id)
    
# Option 2: Clean up all test vector stores (uncomment to use)
#cleanup_all_vector_stores_by_pattern("OpenAI_challenge_")
# Out:
# 🧹 Starting cleanup for vector store vs_68303070059881918b3f51104fa0bcc0
#
# 📄 Deleting files...
# ✓ Deleted file file-VTLwc9sLgTFV8Uc43hxt8C
# ✓ Deleted file file-33q3VhUEjjzkXJSNJb9CMv
# ✓ Deleted file file-GK6JpjbX2aJNPTePRb9qry
# ✓ Deleted file file-LXEXxjgvArfsvDL7WqdRe4
# ✓ Deleted file file-4cHcKBrAdX87eHVFdvpDhz
# ✓ Deleted file file-BPTUPADcy3Sd1giJjmvcM6
# ✓ Deleted file file-WJ7AFiV2qMgu88HiCTPnja
# ✓ Deleted file file-GzSzWKiQKQ1Z4kPe2EdQtc
# ✓ Deleted file file-1QeYfX36y8CgDg6zwMNmqh
# ✓ Deleted file file-FxYM4Jx4vvgKAGUfxLxoHh
# ✓ Deleted file file-PCm2mLGBiLBFopFW9EDt9N
# ✓ Deleted file file-TYMxPJVCfhimxFgtNdKFBF
# ✓ Deleted file file-8DdGyCNvK5qoE9kCSChaFm
# ✓ Deleted file file-5KCPiVc5sQtxkvb9LLYmQn
# ✓ Deleted file file-P9CegFPVceKGRtd3Q81StH
# ✓ Deleted file file-She4nzyt2VVpkDkncHLrSV
# ✓ Deleted file file-Tu77kDMjXAaTRmTjFXaBMP
# ✓ Deleted file file-RbT29neLsHNNJDQqgQAgKc
# ✓ Deleted file file-3L6s6TuqEqnGdcc9phXrW5
# ✓ Deleted file file-9KUysgQZt2QSE4j28DfXn1
# Deleted 20 files
#
# 🗑️  Deleting vector store...
# ✓ Deleted vector store vs_68303070059881918b3f51104fa0bcc0
#
# ✅ Cleanup complete!

# %%
#print("Current storage status:")
#show_storage_summary()

# %%
# Example 1: Delete ALL files (dry run first for safety)
#print("\n" + "="*50)
#print("Preview of deleting ALL files:")
#delete_all_files(dry_run=True)

# %%
delete_all_files(dry_run=False)
# Out:
# Found 221 files
# Total size: 1.33 MB
#
# 🗑️  Deleting files...
# ✓ Deleted question_16_meta-llama_llama-4-scout_online_20250522191209.md (1/221)
# ✓ Deleted question_41_anthropic_claude-3-haiku_online_20250522193647.md (2/221)
# ✓ Deleted deep_research_competition_strategies_ideas.md (3/221)
# ✓ Deleted question_41_meta-llama_llama-4-scout_online_20250522193701.md (4/221)
# ✓ Deleted question_73_meta-llama_llama-4-scout_online_20250522201158.md (5/221)
# ✓ Deleted deep_research_Kuhikugu_Archaeological.md (6/221)
# ✓ Deleted question_15_openai_gpt-4.1-mini_online_20250522191038.md (7/221)
# ✓ Deleted question_71_anthropic_claude-3-haiku_online_20250522200901.md (8/221)
# ✓ Deleted question_31_openai_gpt-4.1-mini_online_20250522192558.md (9/221)
# ✓ Deleted question_70_meta-llama_llama-4-scout_online_20250522200809.md (10/221)
# ✓ Deleted question_32_openai_gpt-4.1-mini_online_20250522192653.md (11/221)
# ✓ Deleted question_4_anthropic_claude-3-haiku_online_20250522185908.md (12/221)
# ✓ Deleted deep_research_Effectiveness_of_LIDAR.md (13/221)
# ✓ Deleted question_57_anthropic_claude-3-haiku_online_20250522195333.md (14/221)
# ✓ Deleted question_43_openai_gpt-4.1-mini_online_20250522193837.md (15/221)
# ✓ Deleted question_5_anthropic_claude-3-haiku_online_20250522190025.md (16/221)
# ✓ Deleted question_3_anthropic_claude-3-haiku_online_20250522185757.md (17/221)
# ✓ Deleted question_51_anthropic_claude-3-haiku_online_20250522194723.md (18/221)
# ✓ Deleted question_69_meta-llama_llama-4-scout_online_20250522200658.md (19/221)
# ✓ Deleted question_17_meta-llama_llama-4-scout_online_20250522191312.md (20/221)
# ✓ Deleted question_67_anthropic_claude-3-haiku_online_20250522200414.md (21/221)
# ✓ Deleted question_9_meta-llama_llama-4-scout_online_20250522190530.md (22/221)
# ✓ Deleted question_76_anthropic_claude-3-haiku_online_20250522201445.md (23/221)
# ✓ Deleted question_65_openai_gpt-4.1-mini_online_20250522200200.md (24/221)
# ✓ Deleted question_53_anthropic_claude-3-haiku_online_20250522194916.md (25/221)
# ✓ Deleted question_73_anthropic_claude-3-haiku_online_20250522201129.md (26/221)
# ✓ Deleted question_29_meta-llama_llama-4-scout_online_20250522192445.md (27/221)
# ✓ Deleted question_42_openai_gpt-4.1-mini_online_20250522193728.md (28/221)
# ✓ Deleted question_8_meta-llama_llama-4-scout_online_20250522190438.md (29/221)
# ✓ Deleted question_11_meta-llama_llama-4-scout_online_20250522190732.md (30/221)
# ✓ Deleted question_51_meta-llama_llama-4-scout_online_20250522194735.md (31/221)
# ✓ Deleted question_45_meta-llama_llama-4-scout_online_20250522194133.md (32/221)
# ✓ Deleted question_49_openai_gpt-4.1-mini_online_20250522194524.md (33/221)
# ✓ Deleted question_6_anthropic_claude-3-haiku_online_20250522190141.md (34/221)
# ✓ Deleted question_44_anthropic_claude-3-haiku_online_20250522193954.md (35/221)
# ✓ Deleted question_2_openai_gpt-4.1-mini_online_20250522185633.md (36/221)
# ✓ Deleted question_74_meta-llama_llama-4-scout_online_20250522201303.md (37/221)
# ✓ Deleted question_53_meta-llama_llama-4-scout_online_20250522194924.md (38/221)
# ✓ Deleted question_30_anthropic_claude-3-haiku_online_20250522192528.md (39/221)
# ✓ Deleted question_38_anthropic_claude-3-haiku_online_20250522193348.md (40/221)
# ✓ Deleted question_15_meta-llama_llama-4-scout_online_20250522191059.md (41/221)
# ✓ Deleted question_32_meta-llama_llama-4-scout_online_20250522192721.md (42/221)
# ✓ Deleted question_56_openai_gpt-4.1-mini_online_20250522195202.md (43/221)
# ✓ Deleted question_59_anthropic_claude-3-haiku_online_20250522195542.md (44/221)
# ✓ Deleted question_68_meta-llama_llama-4-scout_online_20250522200600.md (45/221)
# ✓ Deleted question_22_meta-llama_llama-4-scout_online_20250522191809.md (46/221)
# ✓ Deleted question_29_anthropic_claude-3-haiku_online_20250522192430.md (47/221)
# ✓ Deleted question_4_meta-llama_llama-4-scout_online_20250522185926.md (48/221)
# ✓ Deleted question_13_meta-llama_llama-4-scout_online_20250522190921.md (49/221)
# ✓ Deleted question_14_meta-llama_llama-4-scout_online_20250522191007.md (50/221)
# ✓ Deleted question_31_meta-llama_llama-4-scout_online_20250522192622.md (51/221)
# ✓ Deleted question_55_openai_gpt-4.1-mini_online_20250522195059.md (52/221)
# ✓ Deleted deep_research_Known_Archaeological_Sites.md (53/221)
# ✓ Deleted question_21_anthropic_claude-3-haiku_online_20250522191653.md (54/221)
# ✓ Deleted question_67_openai_gpt-4.1-mini_online_20250522200401.md (55/221)
# ✓ Deleted question_12_anthropic_claude-3-haiku_online_20250522190814.md (56/221)
# ✓ Deleted question_42_anthropic_claude-3-haiku_online_20250522193744.md (57/221)
# ✓ Deleted question_46_anthropic_claude-3-haiku_online_20250522194215.md (58/221)
# ✓ Deleted question_37_anthropic_claude-3-haiku_online_20250522193227.md (59/221)
# ✓ Deleted question_14_openai_gpt-4.1-mini_online_20250522190943.md (60/221)
# ✓ Deleted question_46_meta-llama_llama-4-scout_online_20250522194230.md (61/221)
# ✓ Deleted question_76_openai_gpt-4.1-mini_online_20250522201429.md (62/221)
# ✓ Deleted question_22_anthropic_claude-3-haiku_online_20250522191753.md (63/221)
# ✓ Deleted deep_research_Machine_Learning_Models.md (64/221)
# ✓ Deleted question_75_anthropic_claude-3-haiku_online_20250522201344.md (65/221)
# ✓ Deleted question_71_meta-llama_llama-4-scout_online_20250522200931.md (66/221)
# ✓ Deleted question_12_meta-llama_llama-4-scout_online_20250522190829.md (67/221)
# ✓ Deleted question_24_openai_gpt-4.1-mini_online_20250522191929.md (68/221)
# ✓ Deleted question_10_openai_gpt-4.1-mini_online_20250522190606.md (69/221)
# ✓ Deleted question_23_anthropic_claude-3-haiku_online_20250522191849.md (70/221)
# ✓ Deleted question_45_anthropic_claude-3-haiku_online_20250522194058.md (71/221)
# ✓ Deleted question_73_openai_gpt-4.1-mini_online_20250522201116.md (72/221)
# ✓ Deleted question_47_anthropic_claude-3-haiku_online_20250522194321.md (73/221)
# ✓ Deleted question_58_anthropic_claude-3-haiku_online_20250522195436.md (74/221)
# ✓ Deleted question_21_openai_gpt-4.1-mini_online_20250522191638.md (75/221)
# ✓ Deleted question_56_anthropic_claude-3-haiku_online_20250522195214.md (76/221)
# ✓ Deleted question_54_meta-llama_llama-4-scout_online_20250522195037.md (77/221)
# ✓ Deleted deep_research_Detecting_Archaeological_Sites_SOTA.md (78/221)
# ✓ Deleted question_11_anthropic_claude-3-haiku_online_20250522190717.md (79/221)
# ✓ Deleted question_32_anthropic_claude-3-haiku_online_20250522192708.md (80/221)
# ✓ Deleted question_69_openai_gpt-4.1-mini_online_20250522200628.md (81/221)
# ✓ Deleted question_43_meta-llama_llama-4-scout_online_20250522193907.md (82/221)
# ✓ Deleted question_37_meta-llama_llama-4-scout_online_20250522193306.md (83/221)
# ✓ Deleted question_44_openai_gpt-4.1-mini_online_20250522193937.md (84/221)
# ✓ Deleted question_6_openai_gpt-4.1-mini_online_20250522190126.md (85/221)
# ✓ Deleted question_8_openai_gpt-4.1-mini_online_20250522190346.md (86/221)
# ✓ Deleted question_36_meta-llama_llama-4-scout_online_20250522193143.md (87/221)
# ✓ Deleted question_1_meta-llama_llama-4-scout_online_20250522185601.md (88/221)
# ✓ Deleted question_23_meta-llama_llama-4-scout_online_20250522191901.md (89/221)
# ✓ Deleted question_35_anthropic_claude-3-haiku_online_20250522193015.md (90/221)
# ✓ Deleted question_57_openai_gpt-4.1-mini_online_20250522195315.md (91/221)
# ✓ Deleted question_74_anthropic_claude-3-haiku_online_20250522201242.md (92/221)
# ✓ Deleted question_26_openai_gpt-4.1-mini_online_20250522192145.md (93/221)
# ✓ Deleted question_2_meta-llama_llama-4-scout_online_20250522185705.md (94/221)
# ✓ Deleted question_20_meta-llama_llama-4-scout_online_20250522191603.md (95/221)
# ✓ Deleted question_74_openai_gpt-4.1-mini_online_20250522201227.md (96/221)
# ✓ Deleted question_12_openai_gpt-4.1-mini_online_20250522190759.md (97/221)
# ✓ Deleted question_27_anthropic_claude-3-haiku_online_20250522192247.md (98/221)
# ✓ Deleted question_43_anthropic_claude-3-haiku_online_20250522193852.md (99/221)
# ✓ Deleted question_48_meta-llama_llama-4-scout_online_20250522194456.md (100/221)
# ✓ Deleted question_29_openai_gpt-4.1-mini_online_20250522192419.md (101/221)
# ✓ Deleted question_45_openai_gpt-4.1-mini_online_20250522194046.md (102/221)
# ✓ Deleted question_72_anthropic_claude-3-haiku_online_20250522201015.md (103/221)
# ✓ Deleted question_9_openai_gpt-4.1-mini_online_20250522190505.md (104/221)
# ✓ Deleted question_18_anthropic_claude-3-haiku_online_20250522191347.md (105/221)
# ✓ Deleted question_47_meta-llama_llama-4-scout_online_20250522194342.md (106/221)
# ✓ Deleted question_4_openai_gpt-4.1-mini_online_20250522185853.md (107/221)
# ✓ Deleted question_56_meta-llama_llama-4-scout_online_20250522195241.md (108/221)
# ✓ Deleted question_19_openai_gpt-4.1-mini_online_20250522191434.md (109/221)
# ✓ Deleted question_40_openai_gpt-4.1-mini_online_20250522193538.md (110/221)
# ✓ Deleted question_61_meta-llama_llama-4-scout_online_20250522195749.md (111/221)
# ✓ Deleted question_26_meta-llama_llama-4-scout_online_20250522192213.md (112/221)
# ✓ Deleted question_38_meta-llama_llama-4-scout_online_20250522193414.md (113/221)
# ✓ Deleted question_65_anthropic_claude-3-haiku_online_20250522200217.md (114/221)
# ✓ Deleted question_23_openai_gpt-4.1-mini_online_20250522191835.md (115/221)
# ✓ Deleted question_1_anthropic_claude-3-haiku_online_20250522185546.md (116/221)
# ✓ Deleted question_24_anthropic_claude-3-haiku_online_20250522191941.md (117/221)
# ✓ Deleted question_34_meta-llama_llama-4-scout_online_20250522192936.md (118/221)
# ✓ Deleted question_8_anthropic_claude-3-haiku_online_20250522190359.md (119/221)
# ✓ Deleted question_63_meta-llama_llama-4-scout_online_20250522200016.md (120/221)
# ✓ Deleted question_59_meta-llama_llama-4-scout_online_20250522195604.md (121/221)
# ✓ Deleted question_2_anthropic_claude-3-haiku_online_20250522185649.md (122/221)
# ✓ Deleted question_39_meta-llama_llama-4-scout_online_20250522193510.md (123/221)
# ✓ Deleted question_58_meta-llama_llama-4-scout_online_20250522195502.md (124/221)
# ✓ Deleted question_34_anthropic_claude-3-haiku_online_20250522192917.md (125/221)
# ✓ Deleted question_64_openai_gpt-4.1-mini_online_20250522200056.md (126/221)
# ✓ Deleted question_72_openai_gpt-4.1-mini_online_20250522201000.md (127/221)
# ✓ Deleted question_19_meta-llama_llama-4-scout_online_20250522191518.md (128/221)
# ✓ Deleted question_6_meta-llama_llama-4-scout_online_20250522190157.md (129/221)
# ✓ Deleted question_75_openai_gpt-4.1-mini_online_20250522201330.md (130/221)
# ✓ Deleted question_47_openai_gpt-4.1-mini_online_20250522194259.md (131/221)
# ✓ Deleted question_60_openai_gpt-4.1-mini_online_20250522195625.md (132/221)
# ✓ Deleted question_5_meta-llama_llama-4-scout_online_20250522190051.md (133/221)
# ✓ Deleted deep_research_Likely_Locations_of_Archaeological.md (134/221)
# ✓ Deleted question_3_meta-llama_llama-4-scout_online_20250522185813.md (135/221)
# ✓ Deleted question_39_openai_gpt-4.1-mini_online_20250522193441.md (136/221)
# ✓ Deleted question_61_anthropic_claude-3-haiku_online_20250522195736.md (137/221)
# ✓ Deleted question_66_openai_gpt-4.1-mini_online_20250522200306.md (138/221)
# ✓ Deleted deep_research_Machine_Learning_Models_2.md (139/221)
# ✓ Deleted question_35_meta-llama_llama-4-scout_online_20250522193036.md (140/221)
# ✓ Deleted question_19_anthropic_claude-3-haiku_online_20250522191447.md (141/221)
# ✓ Deleted question_20_openai_gpt-4.1-mini_online_20250522191537.md (142/221)
# ✓ Deleted question_52_meta-llama_llama-4-scout_online_20250522194833.md (143/221)
# ✓ Deleted question_54_anthropic_claude-3-haiku_online_20250522195010.md (144/221)
# ✓ Deleted question_31_anthropic_claude-3-haiku_online_20250522192611.md (145/221)
# ✓ Deleted question_48_openai_gpt-4.1-mini_online_20250522194410.md (146/221)
# ✓ Deleted question_33_meta-llama_llama-4-scout_online_20250522192837.md (147/221)
# ✓ Deleted question_58_openai_gpt-4.1-mini_online_20250522195423.md (148/221)
# ✓ Deleted question_36_openai_gpt-4.1-mini_online_20250522193117.md (149/221)
# ✓ Deleted question_7_meta-llama_llama-4-scout_online_20250522190258.md (150/221)
# ✓ Deleted question_13_openai_gpt-4.1-mini_online_20250522190856.md (151/221)
# ✓ Deleted question_53_openai_gpt-4.1-mini_online_20250522194903.md (152/221)
# ✓ Deleted question_67_meta-llama_llama-4-scout_online_20250522200429.md (153/221)
# ✓ Deleted question_25_openai_gpt-4.1-mini_online_20250522192024.md (154/221)
# ✓ Deleted question_71_openai_gpt-4.1-mini_online_20250522200848.md (155/221)
# ✓ Deleted question_25_anthropic_claude-3-haiku_online_20250522192045.md (156/221)
# ✓ Deleted question_48_anthropic_claude-3-haiku_online_20250522194423.md (157/221)
# ✓ Deleted question_25_meta-llama_llama-4-scout_online_20250522192120.md (158/221)
# ✓ Deleted question_27_meta-llama_llama-4-scout_online_20250522192301.md (159/221)
# ✓ Deleted question_72_meta-llama_llama-4-scout_online_20250522201039.md (160/221)
# ✓ Deleted question_3_openai_gpt-4.1-mini_online_20250522185742.md (161/221)
# ✓ Deleted question_11_openai_gpt-4.1-mini_online_20250522190706.md (162/221)
# ✓ Deleted deep_research_Known_Archaeological_Sites_3.md (163/221)
# ✓ Deleted question_9_anthropic_claude-3-haiku_online_20250522190516.md (164/221)
# ✓ Deleted question_49_meta-llama_llama-4-scout_online_20250522194600.md (165/221)
# ✓ Deleted question_27_openai_gpt-4.1-mini_online_20250522192234.md (166/221)
# ✓ Deleted question_65_meta-llama_llama-4-scout_online_20250522200243.md (167/221)
# ✓ Deleted question_50_meta-llama_llama-4-scout_online_20250522194651.md (168/221)
# ✓ Deleted question_24_meta-llama_llama-4-scout_online_20250522191955.md (169/221)
# ✓ Deleted question_62_anthropic_claude-3-haiku_online_20250522195843.md (170/221)
# ✓ Deleted question_7_anthropic_claude-3-haiku_online_20250522190233.md (171/221)
# ✓ Deleted question_1_openai_gpt-4.1-mini_online_20250522185533.md (172/221)
# ✓ Deleted question_18_openai_gpt-4.1-mini_online_20250522191335.md (173/221)
# ✓ Deleted question_62_meta-llama_llama-4-scout_online_20250522195914.md (174/221)
# ✓ Deleted question_17_openai_gpt-4.1-mini_online_20250522191230.md (175/221)
# ✓ Deleted question_10_meta-llama_llama-4-scout_online_20250522190644.md (176/221)
# ✓ Deleted question_51_openai_gpt-4.1-mini_online_20250522194712.md (177/221)
# ✓ Deleted question_63_openai_gpt-4.1-mini_online_20250522195944.md (178/221)
# ✓ Deleted question_70_openai_gpt-4.1-mini_online_20250522200727.md (179/221)
# ✓ Deleted question_57_meta-llama_llama-4-scout_online_20250522195401.md (180/221)
# ✓ Deleted question_28_anthropic_claude-3-haiku_online_20250522192340.md (181/221)
# ✓ Deleted question_60_meta-llama_llama-4-scout_online_20250522195653.md (182/221)
# ✓ Deleted question_66_anthropic_claude-3-haiku_online_20250522200319.md (183/221)
# ✓ Deleted question_22_openai_gpt-4.1-mini_online_20250522191742.md (184/221)
# ✓ Deleted question_28_meta-llama_llama-4-scout_online_20250522192356.md (185/221)
# ✓ Deleted question_44_meta-llama_llama-4-scout_online_20250522194011.md (186/221)
# ✓ Deleted question_33_openai_gpt-4.1-mini_online_20250522192747.md (187/221)
# ✓ Deleted question_64_anthropic_claude-3-haiku_online_20250522200111.md (188/221)
# ✓ Deleted question_17_anthropic_claude-3-haiku_online_20250522191243.md (189/221)
# ✓ Deleted question_55_anthropic_claude-3-haiku_online_20250522195112.md (190/221)
# ✓ Deleted question_76_meta-llama_llama-4-scout_online_20250522201519.md (191/221)
# ✓ Deleted question_70_anthropic_claude-3-haiku_online_20250522200739.md (192/221)
# ✓ Deleted question_18_meta-llama_llama-4-scout_online_20250522191402.md (193/221)
# ✓ Deleted question_14_anthropic_claude-3-haiku_online_20250522190953.md (194/221)
# ✓ Deleted question_60_anthropic_claude-3-haiku_online_20250522195638.md (195/221)
# ✓ Deleted deep_research_Known_Archaeological_Sites_2.md (196/221)
# ✓ Deleted question_46_openai_gpt-4.1-mini_online_20250522194202.md (197/221)
# ✓ Deleted question_7_openai_gpt-4.1-mini_online_20250522190220.md (198/221)
# ✓ Deleted question_40_anthropic_claude-3-haiku_online_20250522193549.md (199/221)
# ✓ Deleted question_50_openai_gpt-4.1-mini_online_20250522194621.md (200/221)
# ✓ Deleted question_16_anthropic_claude-3-haiku_online_20250522191155.md (201/221)
# ✓ Deleted question_38_openai_gpt-4.1-mini_online_20250522193332.md (202/221)
# ✓ Deleted question_42_meta-llama_llama-4-scout_online_20250522193757.md (203/221)
# ✓ Deleted question_64_meta-llama_llama-4-scout_online_20250522200130.md (204/221)
# ✓ Deleted question_15_anthropic_claude-3-haiku_online_20250522191050.md (205/221)
# ✓ Deleted question_50_anthropic_claude-3-haiku_online_20250522194637.md (206/221)
# ✓ Deleted question_54_openai_gpt-4.1-mini_online_20250522194956.md (207/221)
# ✓ Deleted question_69_anthropic_claude-3-haiku_online_20250522200642.md (208/221)
# ✓ Deleted question_36_anthropic_claude-3-haiku_online_20250522193132.md (209/221)
# ✓ Deleted question_20_anthropic_claude-3-haiku_online_20250522191547.md (210/221)
# ✓ Deleted deep_research_Amazonian_Dark_Earths.md (211/221)
# ✓ Deleted question_55_meta-llama_llama-4-scout_online_20250522195137.md (212/221)
# ✓ Deleted question_41_openai_gpt-4.1-mini_online_20250522193632.md (213/221)
# ✓ Deleted deep_research_Suspected_Unconfirmed_Sites.md (214/221)
# ✓ Deleted question_39_anthropic_claude-3-haiku_online_20250522193456.md (215/221)
# ✓ Deleted question_21_meta-llama_llama-4-scout_online_20250522191708.md (216/221)
# ✓ Deleted question_61_openai_gpt-4.1-mini_online_20250522195723.md (217/221)
# ✓ Deleted question_5_openai_gpt-4.1-mini_online_20250522190010.md (218/221)
# ✓ Deleted question_30_openai_gpt-4.1-mini_online_20250522192511.md (219/221)
# ✓ Deleted question_33_anthropic_claude-3-haiku_online_20250522192802.md (220/221)
# ✓ Deleted question_28_openai_gpt-4.1-mini_online_20250522192331.md (221/221)
#
# ✅ Deletion complete!
#    Deleted: 221
#    Failed: 0
# {'total': 221, 'deleted': 221, 'failed': 0, 'total_bytes': 1394289}

# %%
# Example 2: Delete only assistant files
# delete_all_files(purpose="assistants", dry_run=False)
    
# Example 3: Delete files by name pattern
delete_files_by_name_pattern("question_", dry_run=False)
delete_files_by_name_pattern("deep_research_", dry_run=False)
# Out:
# No files found matching pattern 'question_'
# No files found matching pattern 'deep_research_'
# {'total': 0, 'deleted': 0, 'failed': 0}
